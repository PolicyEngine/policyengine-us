# %%
from policyengine_us.data.datasets.cps.enhanced_cps.calibrate import (
    get_snapshot,
)
from policyengine_us.data.storage import STORAGE_FOLDER
import pandas as pd

from policyengine_us.data.datasets.puf import PUF_2023
from policyengine_us.data import EnhancedCPS_2023, CalibratedPUFExtendedCPS

CalibratedPUFExtendedCPS().generate()

YEARS = ["2023"]  # , "2024", "2025"]
DATASETS = ["puf_2023", "cps_2023", "calibrated_puf_extended_cps"]

dfs = []

for year in YEARS:
    for dataset in DATASETS:
        print(f"Finding snapshot for {dataset} {year}")
        df = get_snapshot(dataset, year)
        df["time_period"] = year
        df["dataset"] = dataset
        dfs.append(df)

df = pd.concat(dfs, ignore_index=True)

df.to_csv(
    STORAGE_FOLDER / "dataset_losses.csv.gz", index=False, compression="gzip"
)
# Out:
# Calibrating weights | Loss = 0.031: 100%|██████████| 10000/10000 [00:56<00:00, 177.16it/s]
# Finding snapshot for puf_2023 2023
# Finding snapshot for cps_2023 2023
# Finding snapshot for calibrated_puf_extended_cps 2023

# %%
from policyengine_us import EnhancedCPS_2023, CalibratedPUFExtendedCPS

EnhancedCPS_2023()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 from policyengine_us import EnhancedCPS_2023, CalibratedPUFExtendedCPS
# ----> 3 CalibratedPUFExtendedCPS().generate()
#       4 EnhancedCPS_2023().generate()
#
# File ~/policyengine/policyengine-us/policyengine_us/data/datasets/cps/enhanced_cps/enhanced_cps.py:23, in CalibratedPUFExtendedCPS.generate(self)
#      21 for year in range(self.time_period, self.time_period + self.num_years):
#      22     year = str(year)
# ---> 23     adjusted_weights = calibrate(
#      24         "puf_extended_cps_2023",
#      25         time_period=year,
#      26         training_log_path=STORAGE_FOLDER / "calibration_log.csv.gz",
#      27     )
#      28     for variable in cps.variables:
#      29         if variable not in new_data:
#
# File ~/policyengine/policyengine-us/policyengine_us/data/datasets/cps/enhanced_cps/calibrate.py:367, in calibrate(dataset, time_period, training_log_path, learning_rate, epochs)
#     353 def calibrate(
#     354     dataset: str,
#     355     time_period: str = "2023",
#    (...)
#     358     epochs: int = 10_000,
#     359 ) -> np.ndarray:
#     360     (
#     361         household_weights,
#     362         weight_adjustment,
#     363         values_df,
#     364         targets,
#     365         targets_array,
#     366         equivalisation_factors_array,
# --> 367     ) = generate_model_variables(dataset, time_period)
#     368     training_log_path = Path(training_log_path)
#     369     if training_log_path.exists():
#
# File ~/policyengine/policyengine-us/policyengine_us/data/datasets/cps/enhanced_cps/calibrate.py:65, in generate_model_variables(dataset, time_period, no_weight_adjustment)
#      62 FINANCIAL_EQUIVALISATION = COUNT_HOUSEHOLDS
#      63 POPULATION_EQUIVALISATION = COUNT_HOUSEHOLDS / 1e5
# ---> 65 is_filer = simulation.calculate("tax_unit_is_filer").values
#      66 household_has_filers = (
#      67     simulation.map_result(is_filer, "tax_unit", "household") > 0
#      68 )
#      70 for variable_name in FINANCIAL_VARIABLES:
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:376, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     373 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     375 try:
# --> 376     result = self._calculate(variable_name, period)
#     377     if isinstance(result, EnumArray) and decode_enums:
#     378         result = result.decode_to_str()
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:569, in Simulation._calculate(self, variable_name, period)
#     567 try:
#     568     self._check_for_cycle(variable.name, period)
# --> 569     array = self._run_formula(variable, population, period)
#     571     # If no result, use the default value and cache it
#     572     if array is None:
#     573         # Check if the variable has a previously defined value
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:847, in Simulation._run_formula(self, variable, population, period)
#     845     array = formula(population, period)
#     846 else:
# --> 847     array = formula(population, period, parameters_at)
#     849 return array
#
# File ~/policyengine/policyengine-us/policyengine_us/variables/gov/irs/tax_unit_is_filer.py:15, in tax_unit_is_filer.formula(tax_unit, period, parameters)
#      14 def formula(tax_unit, period, parameters):
# ---> 15     total_tax = tax_unit("federal_state_income_tax", period)
#      16     return total_tax != 0
#
# File ~/policyengine/policyengine-core/policyengine_core/populations/population.py:134, in Population.__call__(self, variable_name, period, options)
#     130     return self.simulation.calculate_divide(
#     131         variable_name, period, **calculate_kwargs
#     132     )
#     133 else:
# --> 134     return self.simulation.calculate(
#     135         variable_name, period, **calculate_kwargs
#     136     )
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:376, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     373 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     375 try:
# --> 376     result = self._calculate(variable_name, period)
#     377     if isinstance(result, EnumArray) and decode_enums:
#     378         result = result.decode_to_str()
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:569, in Simulation._calculate(self, variable_name, period)
#     567 try:
#     568     self._check_for_cycle(variable.name, period)
# --> 569     array = self._run_formula(variable, population, period)
#     571     # If no result, use the default value and cache it
#     572     if array is None:
#     573         # Check if the variable has a previously defined value
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:782, in Simulation._run_formula(self, variable, population, period)
#     780 for added_variable in adds_list:
#     781     if added_variable in self.tax_benefit_system.variables:
# --> 782         values = values + self.calculate(
#     783             added_variable, period, map_to=variable.entity.key
#     784         )
#     785     else:
#     786         try:
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:376, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     373 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     375 try:
# --> 376     result = self._calculate(variable_name, period)
#     377     if isinstance(result, EnumArray) and decode_enums:
#     378         result = result.decode_to_str()
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:569, in Simulation._calculate(self, variable_name, period)
#     567 try:
#     568     self._check_for_cycle(variable.name, period)
# --> 569     array = self._run_formula(variable, population, period)
#     571     # If no result, use the default value and cache it
#     572     if array is None:
#     573         # Check if the variable has a previously defined value
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:847, in Simulation._run_formula(self, variable, population, period)
#     845     array = formula(population, period)
#     846 else:
# --> 847     array = formula(population, period, parameters_at)
#     849 return array
#
# File ~/policyengine/policyengine-us/policyengine_us/variables/gov/irs/tax/federal_income/income_tax.py:18, in income_tax.formula(person, period, parameters)
#      16     return 0
#      17 else:
# ---> 18     added_components = add(
#      19         person, period, ["income_tax_before_refundable_credits"]
#      20     )
#      21     subtracted_components = add(
#      22         person, period, ["income_tax_refundable_credits"]
#      23     )
#      24     return added_components - subtracted_components
#
# File ~/policyengine/policyengine-core/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/policyengine/policyengine-core/policyengine_core/commons/formulas.py:183, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     181 variable_entity = entity.entity.get_variable(variable).entity
#     182 if variable_entity.key == entity.entity.key:
# --> 183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
#     186         entity.members(variable, period, options=options)
#     187     )
#
# File ~/policyengine/policyengine-core/policyengine_core/populations/population.py:134, in Population.__call__(self, variable_name, period, options)
#     130     return self.simulation.calculate_divide(
#     131         variable_name, period, **calculate_kwargs
#     132     )
#     133 else:
# --> 134     return self.simulation.calculate(
#     135         variable_name, period, **calculate_kwargs
#     136     )
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:376, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     373 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     375 try:
# --> 376     result = self._calculate(variable_name, period)
#     377     if isinstance(result, EnumArray) and decode_enums:
#     378         result = result.decode_to_str()
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:569, in Simulation._calculate(self, variable_name, period)
#     567 try:
#     568     self._check_for_cycle(variable.name, period)
# --> 569     array = self._run_formula(variable, population, period)
#     571     # If no result, use the default value and cache it
#     572     if array is None:
#     573         # Check if the variable has a previously defined value
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:782, in Simulation._run_formula(self, variable, population, period)
#     780 for added_variable in adds_list:
#     781     if added_variable in self.tax_benefit_system.variables:
# --> 782         values = values + self.calculate(
#     783             added_variable, period, map_to=variable.entity.key
#     784         )
#     785     else:
#     786         try:
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:376, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     373 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     375 try:
# --> 376     result = self._calculate(variable_name, period)
#     377     if isinstance(result, EnumArray) and decode_enums:
#     378         result = result.decode_to_str()
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:569, in Simulation._calculate(self, variable_name, period)
#     567 try:
#     568     self._check_for_cycle(variable.name, period)
# --> 569     array = self._run_formula(variable, population, period)
#     571     # If no result, use the default value and cache it
#     572     if array is None:
#     573         # Check if the variable has a previously defined value
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:782, in Simulation._run_formula(self, variable, population, period)
#     780 for added_variable in adds_list:
#     781     if added_variable in self.tax_benefit_system.variables:
# --> 782         values = values + self.calculate(
#     783             added_variable, period, map_to=variable.entity.key
#     784         )
#     785     else:
#     786         try:
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:376, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     373 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     375 try:
# --> 376     result = self._calculate(variable_name, period)
#     377     if isinstance(result, EnumArray) and decode_enums:
#     378         result = result.decode_to_str()
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:569, in Simulation._calculate(self, variable_name, period)
#     567 try:
#     568     self._check_for_cycle(variable.name, period)
# --> 569     array = self._run_formula(variable, population, period)
#     571     # If no result, use the default value and cache it
#     572     if array is None:
#     573         # Check if the variable has a previously defined value
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:847, in Simulation._run_formula(self, variable, population, period)
#     845     array = formula(population, period)
#     846 else:
# --> 847     array = formula(population, period, parameters_at)
#     849 return array
#
# File ~/policyengine/policyengine-us/policyengine_us/variables/gov/irs/tax/federal_income/before_credits/income_tax_main_rates.py:14, in income_tax_main_rates.formula(tax_unit, period, parameters)
#      12 def formula(tax_unit, period, parameters):
#      13     # compute taxable income that is taxed at the main rates
# ---> 14     full_taxable_income = tax_unit("taxable_income", period)
#      15     cg_exclusion = tax_unit(
#      16         "capital_gains_excluded_from_taxable_income", period
#      17     )
#      18     taxinc = max_(0, full_taxable_income - cg_exclusion)
#
# File ~/policyengine/policyengine-core/policyengine_core/populations/population.py:134, in Population.__call__(self, variable_name, period, options)
#     130     return self.simulation.calculate_divide(
#     131         variable_name, period, **calculate_kwargs
#     132     )
#     133 else:
# --> 134     return self.simulation.calculate(
#     135         variable_name, period, **calculate_kwargs
#     136     )
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:376, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     373 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     375 try:
# --> 376     result = self._calculate(variable_name, period)
#     377     if isinstance(result, EnumArray) and decode_enums:
#     378         result = result.decode_to_str()
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:569, in Simulation._calculate(self, variable_name, period)
#     567 try:
#     568     self._check_for_cycle(variable.name, period)
# --> 569     array = self._run_formula(variable, population, period)
#     571     # If no result, use the default value and cache it
#     572     if array is None:
#     573         # Check if the variable has a previously defined value
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:847, in Simulation._run_formula(self, variable, population, period)
#     845     array = formula(population, period)
#     846 else:
# --> 847     array = formula(population, period, parameters_at)
#     849 return array
#
# File ~/policyengine/policyengine-us/policyengine_us/variables/gov/irs/income/taxable_income/taxable_income.py:14, in taxable_income.formula(tax_unit, period, parameters)
#      12 agi = tax_unit("adjusted_gross_income", period)
#      13 exemptions = tax_unit("exemptions", period)
# ---> 14 deductions = tax_unit("taxable_income_deductions", period)
#      15 return max_(0, agi - exemptions - deductions)
#
# File ~/policyengine/policyengine-core/policyengine_core/populations/population.py:134, in Population.__call__(self, variable_name, period, options)
#     130     return self.simulation.calculate_divide(
#     131         variable_name, period, **calculate_kwargs
#     132     )
#     133 else:
# --> 134     return self.simulation.calculate(
#     135         variable_name, period, **calculate_kwargs
#     136     )
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:376, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     373 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     375 try:
# --> 376     result = self._calculate(variable_name, period)
#     377     if isinstance(result, EnumArray) and decode_enums:
#     378         result = result.decode_to_str()
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:569, in Simulation._calculate(self, variable_name, period)
#     567 try:
#     568     self._check_for_cycle(variable.name, period)
# --> 569     array = self._run_formula(variable, population, period)
#     571     # If no result, use the default value and cache it
#     572     if array is None:
#     573         # Check if the variable has a previously defined value
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:847, in Simulation._run_formula(self, variable, population, period)
#     845     array = formula(population, period)
#     846 else:
# --> 847     array = formula(population, period, parameters_at)
#     849 return array
#
# File ~/policyengine/policyengine-us/policyengine_us/variables/gov/irs/income/taxable_income/deductions/taxable_income_deductions.py:12, in taxable_income_deductions.formula(tax_unit, period, parameters)
#      11 def formula(tax_unit, period, parameters):
# ---> 12     itemizes = tax_unit("tax_unit_itemizes", period)
#      13     deductions_if_itemizing = tax_unit(
#      14         "taxable_income_deductions_if_itemizing", period
#      15     )
#      16     deductions_if_not_itemizing = tax_unit(
#      17         "taxable_income_deductions_if_not_itemizing", period
#      18     )
#
# File ~/policyengine/policyengine-core/policyengine_core/populations/population.py:134, in Population.__call__(self, variable_name, period, options)
#     130     return self.simulation.calculate_divide(
#     131         variable_name, period, **calculate_kwargs
#     132     )
#     133 else:
# --> 134     return self.simulation.calculate(
#     135         variable_name, period, **calculate_kwargs
#     136     )
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:376, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     373 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     375 try:
# --> 376     result = self._calculate(variable_name, period)
#     377     if isinstance(result, EnumArray) and decode_enums:
#     378         result = result.decode_to_str()
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:569, in Simulation._calculate(self, variable_name, period)
#     567 try:
#     568     self._check_for_cycle(variable.name, period)
# --> 569     array = self._run_formula(variable, population, period)
#     571     # If no result, use the default value and cache it
#     572     if array is None:
#     573         # Check if the variable has a previously defined value
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:847, in Simulation._run_formula(self, variable, population, period)
#     845     array = formula(population, period)
#     846 else:
# --> 847     array = formula(population, period, parameters_at)
#     849 return array
#
# File ~/policyengine/policyengine-us/policyengine_us/variables/gov/irs/income/taxable_income/deductions/tax_unit_itemizes.py:26, in tax_unit_itemizes.formula(tax_unit, period, parameters)
#      24 standard_deduction = tax_unit("standard_deduction", period)
#      25 p = parameters(period).gov.irs.deductions
# ---> 26 itemized_deductions = add(tax_unit, period, p.itemized_deductions)
#      27 return itemized_deductions > standard_deduction
#
# File ~/policyengine/policyengine-core/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/policyengine/policyengine-core/policyengine_core/commons/formulas.py:183, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     181 variable_entity = entity.entity.get_variable(variable).entity
#     182 if variable_entity.key == entity.entity.key:
# --> 183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
#     186         entity.members(variable, period, options=options)
#     187     )
#
# File ~/policyengine/policyengine-core/policyengine_core/populations/population.py:134, in Population.__call__(self, variable_name, period, options)
#     130     return self.simulation.calculate_divide(
#     131         variable_name, period, **calculate_kwargs
#     132     )
#     133 else:
# --> 134     return self.simulation.calculate(
#     135         variable_name, period, **calculate_kwargs
#     136     )
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:376, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     373 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     375 try:
# --> 376     result = self._calculate(variable_name, period)
#     377     if isinstance(result, EnumArray) and decode_enums:
#     378         result = result.decode_to_str()
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:569, in Simulation._calculate(self, variable_name, period)
#     567 try:
#     568     self._check_for_cycle(variable.name, period)
# --> 569     array = self._run_formula(variable, population, period)
#     571     # If no result, use the default value and cache it
#     572     if array is None:
#     573         # Check if the variable has a previously defined value
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:847, in Simulation._run_formula(self, variable, population, period)
#     845     array = formula(population, period)
#     846 else:
# --> 847     array = formula(population, period, parameters_at)
#     849 return array
#
# File ~/policyengine/policyengine-us/policyengine_us/variables/gov/irs/income/taxable_income/deductions/itemizing/salt_deduction.py:14, in salt_deduction.formula(tax_unit, period, parameters)
#      13 def formula(tax_unit, period, parameters):
# ---> 14     salt_amount = add(
#      15         tax_unit,
#      16         period,
#      17         ["state_and_local_sales_or_income_tax", "real_estate_taxes"],
#      18     )
#      19     salt = parameters(
#      20         period
#      21     ).gov.irs.deductions.itemized.salt_and_real_estate
#      22     cap = salt.cap[tax_unit("filing_status", period)]
#
# File ~/policyengine/policyengine-core/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/policyengine/policyengine-core/policyengine_core/commons/formulas.py:183, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     181 variable_entity = entity.entity.get_variable(variable).entity
#     182 if variable_entity.key == entity.entity.key:
# --> 183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
#     186         entity.members(variable, period, options=options)
#     187     )
#
# File ~/policyengine/policyengine-core/policyengine_core/populations/population.py:134, in Population.__call__(self, variable_name, period, options)
#     130     return self.simulation.calculate_divide(
#     131         variable_name, period, **calculate_kwargs
#     132     )
#     133 else:
# --> 134     return self.simulation.calculate(
#     135         variable_name, period, **calculate_kwargs
#     136     )
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:376, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     373 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     375 try:
# --> 376     result = self._calculate(variable_name, period)
#     377     if isinstance(result, EnumArray) and decode_enums:
#     378         result = result.decode_to_str()
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:569, in Simulation._calculate(self, variable_name, period)
#     567 try:
#     568     self._check_for_cycle(variable.name, period)
# --> 569     array = self._run_formula(variable, population, period)
#     571     # If no result, use the default value and cache it
#     572     if array is None:
#     573         # Check if the variable has a previously defined value
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:847, in Simulation._run_formula(self, variable, population, period)
#     845     array = formula(population, period)
#     846 else:
# --> 847     array = formula(population, period, parameters_at)
#     849 return array
#
# File ~/policyengine/policyengine-us/policyengine_us/variables/gov/irs/income/taxable_income/deductions/itemizing/state_and_local_sales_or_income_tax.py:13, in state_and_local_sales_or_income_tax.formula(tax_unit, period, parameters)
#      11 def formula(tax_unit, period, parameters):
#      12     # Only sales or income tax can be itemized, but not both.
# ---> 13     income_tax = add(
#      14         tax_unit, period, ["state_income_tax", "local_income_tax"]
#      15     )
#      16     sales_tax = add(
#      17         tax_unit, period, ["state_sales_tax", "local_sales_tax"]
#      18     )
#      19     return max_(income_tax, sales_tax)
#
# File ~/policyengine/policyengine-core/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/policyengine/policyengine-core/policyengine_core/commons/formulas.py:183, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     181 variable_entity = entity.entity.get_variable(variable).entity
#     182 if variable_entity.key == entity.entity.key:
# --> 183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
#     186         entity.members(variable, period, options=options)
#     187     )
#
# File ~/policyengine/policyengine-core/policyengine_core/populations/population.py:134, in Population.__call__(self, variable_name, period, options)
#     130     return self.simulation.calculate_divide(
#     131         variable_name, period, **calculate_kwargs
#     132     )
#     133 else:
# --> 134     return self.simulation.calculate(
#     135         variable_name, period, **calculate_kwargs
#     136     )
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:376, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     373 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     375 try:
# --> 376     result = self._calculate(variable_name, period)
#     377     if isinstance(result, EnumArray) and decode_enums:
#     378         result = result.decode_to_str()
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:569, in Simulation._calculate(self, variable_name, period)
#     567 try:
#     568     self._check_for_cycle(variable.name, period)
# --> 569     array = self._run_formula(variable, population, period)
#     571     # If no result, use the default value and cache it
#     572     if array is None:
#     573         # Check if the variable has a previously defined value
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:847, in Simulation._run_formula(self, variable, population, period)
#     845     array = formula(population, period)
#     846 else:
# --> 847     array = formula(population, period, parameters_at)
#     849 return array
#
# File ~/policyengine/policyengine-us/policyengine_us/variables/gov/states/tax/income/state_income_tax.py:27, in state_income_tax.formula(tax_unit, period, parameters)
#      25 else:
#      26     p = parameters(period)
# ---> 27     return add(tax_unit, period, p.gov.state_income_tax)
#
# File ~/policyengine/policyengine-core/policyengine_core/commons/formulas.py:227, in add(entity, period, variables, options)
#     207 def add(
#     208     entity: Population,
#     209     period: Period,
#     210     variables: List[str],
#     211     options: List[str] = None,
#     212 ):
#     213     """Sums a list of variables.
#     214
#     215     Args:
#    (...)
#     225         ArrayLike: The result of the operation.
#     226     """
# --> 227     return for_each_variable(
#     228         entity, period, variables, agg_func="add", options=options
#     229     )
#
# File ~/policyengine/policyengine-core/policyengine_core/commons/formulas.py:183, in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     181 variable_entity = entity.entity.get_variable(variable).entity
#     182 if variable_entity.key == entity.entity.key:
# --> 183     values = entity(variable, period, options=options)
#     184 elif variable_entity.is_person:
#     185     values = group_agg_func(
#     186         entity.members(variable, period, options=options)
#     187     )
#
# File ~/policyengine/policyengine-core/policyengine_core/populations/population.py:134, in Population.__call__(self, variable_name, period, options)
#     130     return self.simulation.calculate_divide(
#     131         variable_name, period, **calculate_kwargs
#     132     )
#     133 else:
# --> 134     return self.simulation.calculate(
#     135         variable_name, period, **calculate_kwargs
#     136     )
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:376, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     373 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     375 try:
# --> 376     result = self._calculate(variable_name, period)
#     377     if isinstance(result, EnumArray) and decode_enums:
#     378         result = result.decode_to_str()
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:569, in Simulation._calculate(self, variable_name, period)
#     567 try:
#     568     self._check_for_cycle(variable.name, period)
# --> 569     array = self._run_formula(variable, population, period)
#     571     # If no result, use the default value and cache it
#     572     if array is None:
#     573         # Check if the variable has a previously defined value
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:782, in Simulation._run_formula(self, variable, population, period)
#     780 for added_variable in adds_list:
#     781     if added_variable in self.tax_benefit_system.variables:
# --> 782         values = values + self.calculate(
#     783             added_variable, period, map_to=variable.entity.key
#     784         )
#     785     else:
#     786         try:
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:376, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     373 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     375 try:
# --> 376     result = self._calculate(variable_name, period)
#     377     if isinstance(result, EnumArray) and decode_enums:
#     378         result = result.decode_to_str()
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:569, in Simulation._calculate(self, variable_name, period)
#     567 try:
#     568     self._check_for_cycle(variable.name, period)
# --> 569     array = self._run_formula(variable, population, period)
#     571     # If no result, use the default value and cache it
#     572     if array is None:
#     573         # Check if the variable has a previously defined value
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:847, in Simulation._run_formula(self, variable, population, period)
#     845     array = formula(population, period)
#     846 else:
# --> 847     array = formula(population, period, parameters_at)
#     849 return array
#
# File ~/policyengine/policyengine-us/policyengine_us/variables/gov/states/pa/tax/income/pa_use_tax.py:19, in pa_use_tax.formula(tax_unit, period, parameters)
#      14 income = tax_unit("pa_total_taxable_income", period)
#      15 # Parameters vary depending on whether filer is in
#      16 # - Philadelphia (county==city)
#      17 # - Allegheny County
#      18 # - Rest of PA
# ---> 19 county = tax_unit.household("county_str", period)
#      20 # counties = county.possible_values
#      22 philadelphia = county == "PHILADELPHIA_COUNTY_PA"
#
# File ~/policyengine/policyengine-core/policyengine_core/projectors/projector.py:33, in Projector.__call__(self, *args, **kwargs)
#      32 def __call__(self, *args, **kwargs):
# ---> 33     result = self.reference_entity(*args, **kwargs)
#      34     return self.transform_and_bubble_up(result)
#
# File ~/policyengine/policyengine-core/policyengine_core/populations/population.py:134, in Population.__call__(self, variable_name, period, options)
#     130     return self.simulation.calculate_divide(
#     131         variable_name, period, **calculate_kwargs
#     132     )
#     133 else:
# --> 134     return self.simulation.calculate(
#     135         variable_name, period, **calculate_kwargs
#     136     )
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:376, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     373 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     375 try:
# --> 376     result = self._calculate(variable_name, period)
#     377     if isinstance(result, EnumArray) and decode_enums:
#     378         result = result.decode_to_str()
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:569, in Simulation._calculate(self, variable_name, period)
#     567 try:
#     568     self._check_for_cycle(variable.name, period)
# --> 569     array = self._run_formula(variable, population, period)
#     571     # If no result, use the default value and cache it
#     572     if array is None:
#     573         # Check if the variable has a previously defined value
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:847, in Simulation._run_formula(self, variable, population, period)
#     845     array = formula(population, period)
#     846 else:
# --> 847     array = formula(population, period, parameters_at)
#     849 return array
#
# File ~/policyengine/policyengine-us/policyengine_us/variables/household/demographic/geographic/county/county_str.py:12, in county_str.formula(household, period, parameters)
#      11 def formula(household, period, parameters):
# ---> 12     return household("county", period).decode_to_str()
#
# File ~/policyengine/policyengine-core/policyengine_core/populations/population.py:134, in Population.__call__(self, variable_name, period, options)
#     130     return self.simulation.calculate_divide(
#     131         variable_name, period, **calculate_kwargs
#     132     )
#     133 else:
# --> 134     return self.simulation.calculate(
#     135         variable_name, period, **calculate_kwargs
#     136     )
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:376, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     373 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     375 try:
# --> 376     result = self._calculate(variable_name, period)
#     377     if isinstance(result, EnumArray) and decode_enums:
#     378         result = result.decode_to_str()
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:569, in Simulation._calculate(self, variable_name, period)
#     567 try:
#     568     self._check_for_cycle(variable.name, period)
# --> 569     array = self._run_formula(variable, population, period)
#     571     # If no result, use the default value and cache it
#     572     if array is None:
#     573         # Check if the variable has a previously defined value
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:847, in Simulation._run_formula(self, variable, population, period)
#     845     array = formula(population, period)
#     846 else:
# --> 847     array = formula(population, period, parameters_at)
#     849 return array
#
# File ~/policyengine/policyengine-us/policyengine_us/variables/household/demographic/geographic/county/county.py:17, in county.formula(household, period, parameters)
#      15 def formula(household, period, parameters):
#      16     # Attempt to look up from ZIP code
# ---> 17     zip_code = household("zip_code", period).astype(int)
#      18     zip_codes = ZIP_CODE_DATASET.set_index("zip_code")
#      19     county_name = zip_codes.county[zip_code]
#
# File ~/policyengine/policyengine-core/policyengine_core/populations/population.py:134, in Population.__call__(self, variable_name, period, options)
#     130     return self.simulation.calculate_divide(
#     131         variable_name, period, **calculate_kwargs
#     132     )
#     133 else:
# --> 134     return self.simulation.calculate(
#     135         variable_name, period, **calculate_kwargs
#     136     )
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/microsimulation.py:54, in Microsimulation.calculate(self, variable_name, period, map_to, use_weights, decode_enums)
#      52 elif period is None and self.default_calculation_period is not None:
#      53     period = get_period(self.default_calculation_period)
# ---> 54 values = super().calculate(variable_name, period, map_to, decode_enums)
#      55 if not use_weights:
#      56     return values
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:376, in Simulation.calculate(self, variable_name, period, map_to, decode_enums)
#     373 np.random.seed(hash(variable_name + str(period)) % 1000000)
#     375 try:
# --> 376     result = self._calculate(variable_name, period)
#     377     if isinstance(result, EnumArray) and decode_enums:
#     378         result = result.decode_to_str()
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:569, in Simulation._calculate(self, variable_name, period)
#     567 try:
#     568     self._check_for_cycle(variable.name, period)
# --> 569     array = self._run_formula(variable, population, period)
#     571     # If no result, use the default value and cache it
#     572     if array is None:
#     573         # Check if the variable has a previously defined value
#
# File ~/policyengine/policyengine-core/policyengine_core/simulations/simulation.py:847, in Simulation._run_formula(self, variable, population, period)
#     845     array = formula(population, period)
#     846 else:
# --> 847     array = formula(population, period, parameters_at)
#     849 return array
#
# File ~/policyengine/policyengine-us/policyengine_us/variables/household/demographic/geographic/zip_code/zip_code.py:34, in zip_code.formula(household, period, parameters)
#      32     for state in ZIP_CODE_DATASET.state.unique():
#      33         count_households_in_state = (state_code == state).sum()
# ---> 34         household_zip_code[state_code == state] = (
#      35             ZIP_CODE_DATASET[ZIP_CODE_DATASET.state == state]
#      36             .sample(
#      37                 count_households_in_state,
#      38                 weights="population",
#      39                 replace=True,
#      40             )
#      41             .zip_code
#      42         )
#      43     household_zip_code = pd.Series(household_zip_code)
#      45 return household_zip_code.astype(str).str.zfill(5)
#
# KeyboardInterrupt:
