# %%
from policyengine_us.model_api import *

def create_eitc_winship_reform():
    # Compute EITC under filer_earned = tax_unit_head_earned
    # Then compute EITC under filer_earned = tax_unit_spouse_earned
    # Then set EITC = sum of the two

    class original_eitc(Variable):
        value_type = float
        entity = TaxUnit
        definition_period = YEAR
        label = "Original EITC"
        reference = "https://www.law.cornell.edu/uscode/text/26/32#a"
        unit = USD
        defined_for = "eitc_eligible"

        def formula(tax_unit, period, parameters):
            maximum = tax_unit("eitc_maximum", period)
            phased_in = tax_unit("eitc_phased_in", period)
            reduction = tax_unit("eitc_reduction", period)
            limitation = max_(0, maximum - reduction)
            return min_(phased_in, limitation)
        
    class earned_income_tax_credit(Variable):
        value_type = float
        entity = TaxUnit
        definition_period = YEAR
        label = "EITC"
        unit = USD
        defined_for = "eitc_eligible"

        def formula(tax_unit, period, parameters):
            person = tax_unit.members
            simulation = tax_unit.simulation
            agi = tax_unit("adjusted_gross_income", period)
            earned_income = person("earned", period)
            is_head = person("is_tax_unit_head", period)
            is_spouse = person("is_tax_unit_spouse", period)

            filer_earned_head_only = tax_unit.sum(earned_income * is_head)
            filer_earned_spouse_only = tax_unit.sum(earned_income * is_spouse)

            head_only_branch = simulation.get_branch("head_only")
            head_only_branch.set_input("filer_earned", period, filer_earned_head_only)
            head_only_branch.set_input("adjusted_gross_income", period, filer_earned_head_only)
            head_eitc = head_only_branch.calculate("original_eitc", period)

            spouse_only_branch = simulation.get_branch("spouse_only")
            spouse_only_branch.set_input("filer_earned", period, filer_earned_spouse_only)
            spouse_only_branch.set_input("adjusted_gross_income", period, filer_earned_spouse_only)
            spouse_eitc = spouse_only_branch.calculate("original_eitc", period)

            return (agi < 100_000) * (head_eitc + spouse_eitc)
    
    class winship_eitc_reform(Reform):
        def apply(self):
            self.add_variable(original_eitc)
            self.update_variable(earned_income_tax_credit)
    
    return winship_eitc_reform

# %%
from policyengine_us import Microsimulation

baseline = Microsimulation()
reformed = Microsimulation(reform=create_eitc_winship_reform())

reformed.calculate("household_net_income", 2023).sum() - baseline.calculate("household_net_income", 2023).sum()
# Out:
# 39961936581.42383

# %%
(reformed.calculate("household_net_income", 2023).sum() - baseline.calculate("household_net_income", 2023).sum()) / 1e9
# Out:
# 39.96193658142383

# %%
from policyengine_us import Simulation

simulation = Simulation(
    reform=create_eitc_winship_reform(),
    situation={
        "people": {
            "head": {
                "employment_income": 10_000
            },
            "spouse": {
                "employment_income": 30_000
            },
            "child": {
                "age": 5
            },
        },
        "tax_units": {
            "tax_unit": {
                "members": ["head", "spouse", "child"]
            }
        }
    }
)

simulation.trace = True
simulation.calculate("earned_income_tax_credit")
simulation.tracer.print_computation_log()
# Out:
#   earned_income_tax_credit<2022, (default)> = [6535.348]
#     eitc_eligible<2022, (default)> = [ True]
#       tax_unit_children<2022, (default)> = [1.]
#         is_child<2022, (default)> = [False False  True]
#           age<2022, (default)> = [40. 40.  5.]
#       age<2022, (default)> = [40. 40.  5.]
#       eitc_relevant_investment_income<2022, (default)> = [0.]
#         capital_gains<2022, (default)> = [0. 0. 0.]
#           short_term_capital_gains<2022, (default)> = [0. 0. 0.]
#           long_term_capital_gains<2022, (default)> = [0. 0. 0.]
#         net_investment_income<2022, (default)> = [0.]
#           taxable_interest_income<2022, (default)> = [0. 0. 0.]
#           dividend_income<2022, (default)> = [0. 0. 0.]
#             qualified_dividend_income<2022, (default)> = [0. 0. 0.]
#             non_qualified_dividend_income<2022, (default)> = [0. 0. 0.]
#           rental_income<2022, (default)> = [0. 0. 0.]
#           c01000<2022, (default)> = [0.]
#             sep<2022, (default)> = [1]
#             c23650<2022, (default)> = [0.]
#               long_term_capital_gains<2022, (default)> = [0. 0. 0.]
#               short_term_capital_gains<2022, (default)> = [0. 0. 0.]
#         tax_exempt_interest_income<2022, (default)> = [0. 0. 0.]
#         c01000<2022, (default)> = [0.]
#     earned<2022, (default)> = [10000. 30000.     0.]
#       self_employment_tax<2022, (default)> = [0. 0. 0.]
#         self_employment_social_security_tax<2022, (default)> = [0. 0. 0.]
#           social_security_taxable_self_employment_income<2022, (default)> = [0. 0. 0.]
#             taxable_self_employment_income<2022, (default)> = [0. 0. 0.]
#               sey<2022, (default)> = [0. 0. 0.]
#                 self_employment_income<2022, (default)> = [0. 0. 0.]
#                 farm_income<2022, (default)> = [0. 0. 0.]
#                 k1bx14<2022, (default)> = [0. 0. 0.]
#             taxable_earnings_for_social_security<2022, (default)> = [10000. 30000.     0.]
#               payroll_tax_gross_wages<2022, (default)> = [10000. 30000.     0.]
#                 employment_income<2022, (default)> = [10000. 30000.     0.]
#         self_employment_medicare_tax<2022, (default)> = [0. 0. 0.]
#           taxable_self_employment_income<2022, (default)> = [0. 0. 0.]
#       earned_income<2022, (default)> = [10000. 30000.     0.]
#         employment_income<2022, (default)> = [10000. 30000.     0.]
#         self_employment_income<2022, (default)> = [0. 0. 0.]
#     is_tax_unit_head<2022, (default)> = [ True False False]
#       is_child<2022, (default)> = [False False  True]
#       age<2022, (default)> = [40. 40.  5.]
#     is_tax_unit_spouse<2022, (default)> = [False  True False]
#       is_child<2022, (default)> = [False False  True]
#       is_tax_unit_head<2022, (default)> = [ True False False]
#       age<2022, (default)> = [40. 40.  5.]
#     original_eitc<2022, (head_only)> = [3400.]
#       eitc_eligible<2022, (head_only)> = [ True]
#       eitc_maximum<2022, (head_only)> = [3733.]
#         eitc_child_count<2022, (head_only)> = [1]
#           is_eitc_qualifying_child<2022, (head_only)> = [False False  True]
#             is_tax_unit_dependent<2022, (head_only)> = [False False  True]
#               is_tax_unit_head<2022, (head_only)> = [ True False False]
#               is_tax_unit_spouse<2022, (head_only)> = [False  True False]
#             is_permanently_and_totally_disabled<2022, (head_only)> = [False False False]
#             age<2022, (head_only)> = [40. 40.  5.]
#             is_full_time_student<2022, (head_only)> = [False False  True]
#               is_full_time_college_student<2022, (head_only)> = [False False False]
#               is_in_k12_school<2022, (head_only)> = [False False  True]
#                 age<2022, (head_only)> = [40. 40.  5.]
#       eitc_phased_in<2022, (head_only)> = [3400.]
#         eitc_maximum<2022, (head_only)> = [3733.]
#         eitc_phase_in_rate<2022, (head_only)> = [0.34]
#           eitc_child_count<2022, (head_only)> = [1]
#         filer_earned<2022, (head_only)> = [10000.]
#       eitc_reduction<2022, (head_only)> = [0.]
#         filer_earned<2022, (head_only)> = [10000.]
#         adjusted_gross_income<2022, (head_only)> = [10000.]
#         eitc_phase_out_start<2022, (head_only)> = [26260.]
#           eitc_child_count<2022, (head_only)> = [1]
#           tax_unit_is_joint<2022, (head_only)> = [ True]
#             filing_status<2022, (head_only)> = ['JOINT']
#               is_tax_unit_spouse<2022, (head_only)> = [False  True False]
#               tax_unit_dependents<2022, (head_only)> = [1]
#                 is_tax_unit_dependent<2022, (head_only)> = [False False  True]
#         eitc_phase_out_rate<2022, (head_only)> = [0.1598]
#           eitc_child_count<2022, (head_only)> = [1]
#     original_eitc<2022, (spouse_only)> = [3135.3481]
#       eitc_eligible<2022, (spouse_only)> = [ True]
#       eitc_maximum<2022, (spouse_only)> = [3733.]
#         eitc_child_count<2022, (spouse_only)> = [1]
#           is_eitc_qualifying_child<2022, (spouse_only)> = [False False  True]
#             is_tax_unit_dependent<2022, (spouse_only)> = [False False  True]
#               is_tax_unit_head<2022, (spouse_only)> = [ True False False]
#               is_tax_unit_spouse<2022, (spouse_only)> = [False  True False]
#             is_permanently_and_totally_disabled<2022, (spouse_only)> = [False False False]
#             age<2022, (spouse_only)> = [40. 40.  5.]
#             is_full_time_student<2022, (spouse_only)> = [False False  True]
#               is_full_time_college_student<2022, (spouse_only)> = [False False False]
#               is_in_k12_school<2022, (spouse_only)> = [False False  True]
#                 age<2022, (spouse_only)> = [40. 40.  5.]
#       eitc_phased_in<2022, (spouse_only)> = [3733.]
#         eitc_maximum<2022, (spouse_only)> = [3733.]
#         eitc_phase_in_rate<2022, (spouse_only)> = [0.34]
#           eitc_child_count<2022, (spouse_only)> = [1]
#         filer_earned<2022, (spouse_only)> = [30000.]
#       eitc_reduction<2022, (spouse_only)> = [597.652]
#         filer_earned<2022, (spouse_only)> = [30000.]
#         adjusted_gross_income<2022, (spouse_only)> = [30000.]
#         eitc_phase_out_start<2022, (spouse_only)> = [26260.]
#           eitc_child_count<2022, (spouse_only)> = [1]
#           tax_unit_is_joint<2022, (spouse_only)> = [ True]
#             filing_status<2022, (spouse_only)> = ['JOINT']
#               is_tax_unit_spouse<2022, (spouse_only)> = [False  True False]
#               tax_unit_dependents<2022, (spouse_only)> = [1]
#                 is_tax_unit_dependent<2022, (spouse_only)> = [False False  True]
#         eitc_phase_out_rate<2022, (spouse_only)> = [0.1598]
#           eitc_child_count<2022, (spouse_only)> = [1]
