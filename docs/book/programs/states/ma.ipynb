# %% [markdown]
# # Massachusetts tax and benefit system
#
# This notebook shows how the state and federal tax and benefit system affects Massachusetts residents holistically.
#
# ## Examples

# %%
from openfisca_us import IndividualSim
import pandas as pd
import plotly.express as px


def make_tax(adults, children):
    sim = IndividualSim(year=2022)
    sim.add_person(name="head", age=25)
    members = ["head"]
    if adults == 2:
        sim.add_person(name="spouse")
        members += ["spouse"]
    for i in range(children):
        child = "child{}".format(i)
        sim.add_person(name=child, age=6)
        members += [child]
    sim.add_tax_unit(name="tax_unit", members=members)
    sim.add_spm_unit(name="spm_unit", members=members, rent=12_000)
    sim.add_household(name="household", members=members, state_code="MA")
    sim.vary("employment_income", max=100_000, step=100)
    return pd.DataFrame(
        dict(
            employment_income=sim.calc("employment_income")[0],
            spm_unit_net_income=sim.calc("spm_unit_net_income")[0].round(),
            mtr=-sim.deriv(
                "spm_unit_net_income", "employment_income", wrt_target="head"
            ),
            adults=adults,
            children=children,
        )
    )


# Make a table of state taxes for different numbers of adults and children.
l = []
for adults in range(1, 3):
    for children in range(0, 4):
        l.append(make_tax(adults, children))

df = pd.concat(l)

LABELS = dict(
    employment_income="Employment income",
    spm_unit_net_income="Net income",
    mtr="Marginal tax rate",
    adults="Adults",
    children="Children",
)

fig = px.line(
    df,
    "employment_income",
    "spm_unit_net_income",
    color="children",
    animation_frame="adults",
    labels=LABELS,
    title="Net income for a Massachusetts household",
)
fig.update_layout(xaxis_tickformat="$,", yaxis_tickformat="$,")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/hypothetical.py in calc(self, var, period, target, index, reform)
#     193         try:
# --> 194             result = self.simulation.calculate(var, period)
#     195         except:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/income/spm_unit/spm_unit_net_income.py in formula(spm_unit, period, parameters)
#      17         market_income = spm_unit("spm_unit_market_income", period)
# ---> 18         benefits = spm_unit("spm_unit_benefits", period)
#      19         taxes = spm_unit("spm_unit_taxes", period)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api.py in sum_of_variables(entity, period, parameters)
#     324             variable_names = variables
# --> 325         return add(entity, period, variable_names)
#     326
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api.py in add(entity, period, variables, options)
#     123     return for_each_variable(
# --> 124         entity, period, variables, agg_func="add", options=options
#     125     )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#      85         if variable_entity.key == entity.entity.key:
# ---> 86             values = entity(variable, period, options=options)
#      87         else:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/snap.py in formula(spm_unit, period, parameters)
#      14         ALLOTMENTS = ["snap_normal_allotment", "snap_emergency_allotment"]
# ---> 15         return add(spm_unit, period, ALLOTMENTS)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api.py in add(entity, period, variables, options)
#     123     return for_each_variable(
# --> 124         entity, period, variables, agg_func="add", options=options
#     125     )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#      85         if variable_entity.key == entity.entity.key:
# ---> 86             values = entity(variable, period, options=options)
#      87         else:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/snap_normal_allotment.py in formula(spm_unit, period, parameters)
#      15         # also defines state powers to modify the rules.
# ---> 16         eligible = spm_unit("is_snap_eligible", period)
#      17         expected_contribution = spm_unit("snap_expected_contribution", period)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/eligibility/is_snap_eligible.py in formula(spm_unit, period, parameters)
#      15     def formula(spm_unit, period, parameters):
# ---> 16         net = spm_unit("meets_snap_net_income_test", period)
#      17         gross = spm_unit("meets_snap_gross_income_test", period)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/eligibility/meets_snap_net_income_test.py in formula(spm_unit, period, parameters)
#      16         net_income_limit_fpg = parameters(period).usda.snap.income.limit.net
# ---> 17         net_income_fpg = spm_unit("snap_net_income_fpg_ratio", period)
#      18         return net_income_fpg <= net_income_limit_fpg
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     229         if formula.__code__.co_argcount == 2:
# --> 230             array = formula(population, period)
#     231         else:
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/income/snap_net_income_fpg_ratio.py in formula(spm_unit, period)
#      14     def formula(spm_unit, period):
# ---> 15         income = spm_unit("snap_net_income", period)
#      16         fpg = spm_unit("spm_unit_fpg", period)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     229         if formula.__code__.co_argcount == 2:
# --> 230             array = formula(population, period)
#     231         else:
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/income/snap_net_income.py in formula(spm_unit, period)
#      14         gross_income = spm_unit("snap_gross_income", period)
# ---> 15         deductions = spm_unit("snap_deductions", period)
#      16         return max_(0, gross_income - deductions)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/income/deductions/snap_deductions.py in formula(spm_unit, period, parameters)
#      14         snap_deductions = parameters(period).usda.snap.income.deductions
# ---> 15         return add(spm_unit, period, snap_deductions.allowed)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api.py in add(entity, period, variables, options)
#     123     return for_each_variable(
# --> 124         entity, period, variables, agg_func="add", options=options
#     125     )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#      85         if variable_entity.key == entity.entity.key:
# ---> 86             values = entity(variable, period, options=options)
#      87         else:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/income/deductions/snap_excess_medical_expense_deduction.py in formula(spm_unit, period, parameters)
#      29         state = spm_unit.household("state_code_str", period)
# ---> 30         standard = p.standard[state] * 12
#      31         standard_claimable = where(excess > 0, standard, 0)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/tracers/tracing_parameter_node_at_instant.py in __getitem__(self, key)
#      43             ) -> Union[TracingParameterNodeAtInstant, Child]:
# ---> 44         child = self.parameter_node_at_instant[key]
#      45         return self.get_traced_child(child, key)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/parameters/parameter_node_at_instant.py in __getitem__(self, key)
#      43         if isinstance(key, numpy.ndarray):
# ---> 44             return parameters.VectorialParameterNodeAtInstant.build_from_node(self)[key]
#      45         return self._children[key]
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/parameters/vectorial_parameter_node_at_instant.py in __getitem__(self, key)
#     157             names = list(self.dtype.names)  # Get all the names of the subnodes, e.g. ['zone_1', 'zone_2']
# --> 158             default = numpy.full_like(self.vector[key[0]], numpy.nan)  # In case of unexpected key, we will set the corresponding value to NaN.
#     159             conditions = [key == name for name in names]
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/numpy/core/records.py in __getitem__(self, indx)
#     518     def __getitem__(self, indx):
# --> 519         obj = super(recarray, self).__getitem__(indx)
#     520
#
# ValueError: no field of name MA
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/hypothetical.py in calc(self, var, period, target, index, reform)
#     196             try:
# --> 197                 result = self.sim.calculate_add(var, period)
#     198             except:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate_add(self, variable_name, period)
#     168             self.calculate(variable_name, sub_period)
# --> 169             for sub_period in period.get_subperiods(variable.definition_period)
#     170             )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in <genexpr>(.0)
#     168             self.calculate(variable_name, sub_period)
# --> 169             for sub_period in period.get_subperiods(variable.definition_period)
#     170             )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/income/spm_unit/spm_unit_net_income.py in formula(spm_unit, period, parameters)
#      17         market_income = spm_unit("spm_unit_market_income", period)
# ---> 18         benefits = spm_unit("spm_unit_benefits", period)
#      19         taxes = spm_unit("spm_unit_taxes", period)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api.py in sum_of_variables(entity, period, parameters)
#     324             variable_names = variables
# --> 325         return add(entity, period, variable_names)
#     326
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api.py in add(entity, period, variables, options)
#     123     return for_each_variable(
# --> 124         entity, period, variables, agg_func="add", options=options
#     125     )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#      85         if variable_entity.key == entity.entity.key:
# ---> 86             values = entity(variable, period, options=options)
#      87         else:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/snap.py in formula(spm_unit, period, parameters)
#      14         ALLOTMENTS = ["snap_normal_allotment", "snap_emergency_allotment"]
# ---> 15         return add(spm_unit, period, ALLOTMENTS)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api.py in add(entity, period, variables, options)
#     123     return for_each_variable(
# --> 124         entity, period, variables, agg_func="add", options=options
#     125     )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#      85         if variable_entity.key == entity.entity.key:
# ---> 86             values = entity(variable, period, options=options)
#      87         else:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/snap_normal_allotment.py in formula(spm_unit, period, parameters)
#      15         # also defines state powers to modify the rules.
# ---> 16         eligible = spm_unit("is_snap_eligible", period)
#      17         expected_contribution = spm_unit("snap_expected_contribution", period)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/eligibility/is_snap_eligible.py in formula(spm_unit, period, parameters)
#      15     def formula(spm_unit, period, parameters):
# ---> 16         net = spm_unit("meets_snap_net_income_test", period)
#      17         gross = spm_unit("meets_snap_gross_income_test", period)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/eligibility/meets_snap_net_income_test.py in formula(spm_unit, period, parameters)
#      16         net_income_limit_fpg = parameters(period).usda.snap.income.limit.net
# ---> 17         net_income_fpg = spm_unit("snap_net_income_fpg_ratio", period)
#      18         return net_income_fpg <= net_income_limit_fpg
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     229         if formula.__code__.co_argcount == 2:
# --> 230             array = formula(population, period)
#     231         else:
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/income/snap_net_income_fpg_ratio.py in formula(spm_unit, period)
#      14     def formula(spm_unit, period):
# ---> 15         income = spm_unit("snap_net_income", period)
#      16         fpg = spm_unit("spm_unit_fpg", period)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     229         if formula.__code__.co_argcount == 2:
# --> 230             array = formula(population, period)
#     231         else:
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/income/snap_net_income.py in formula(spm_unit, period)
#      14         gross_income = spm_unit("snap_gross_income", period)
# ---> 15         deductions = spm_unit("snap_deductions", period)
#      16         return max_(0, gross_income - deductions)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/income/deductions/snap_deductions.py in formula(spm_unit, period, parameters)
#      14         snap_deductions = parameters(period).usda.snap.income.deductions
# ---> 15         return add(spm_unit, period, snap_deductions.allowed)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api.py in add(entity, period, variables, options)
#     123     return for_each_variable(
# --> 124         entity, period, variables, agg_func="add", options=options
#     125     )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#      85         if variable_entity.key == entity.entity.key:
# ---> 86             values = entity(variable, period, options=options)
#      87         else:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/income/deductions/snap_excess_medical_expense_deduction.py in formula(spm_unit, period, parameters)
#      29         state = spm_unit.household("state_code_str", period)
# ---> 30         standard = p.standard[state] * 12
#      31         standard_claimable = where(excess > 0, standard, 0)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/tracers/tracing_parameter_node_at_instant.py in __getitem__(self, key)
#      43             ) -> Union[TracingParameterNodeAtInstant, Child]:
# ---> 44         child = self.parameter_node_at_instant[key]
#      45         return self.get_traced_child(child, key)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/parameters/parameter_node_at_instant.py in __getitem__(self, key)
#      43         if isinstance(key, numpy.ndarray):
# ---> 44             return parameters.VectorialParameterNodeAtInstant.build_from_node(self)[key]
#      45         return self._children[key]
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/parameters/vectorial_parameter_node_at_instant.py in __getitem__(self, key)
#     157             names = list(self.dtype.names)  # Get all the names of the subnodes, e.g. ['zone_1', 'zone_2']
# --> 158             default = numpy.full_like(self.vector[key[0]], numpy.nan)  # In case of unexpected key, we will set the corresponding value to NaN.
#     159             conditions = [key == name for name in names]
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/numpy/core/records.py in __getitem__(self, indx)
#     518     def __getitem__(self, indx):
# --> 519         obj = super(recarray, self).__getitem__(indx)
#     520
#
# ValueError: no field of name MA
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/4k/gjnmnbfs7rqdzdrrc6v_x7yc0000gn/T/ipykernel_89967/475419320.py in <module>
#      36 for adults in range(1, 3):
#      37     for children in range(0, 4):
# ---> 38         l.append(make_tax(adults, children))
#      39
#      40 df = pd.concat(l)
#
# /var/folders/4k/gjnmnbfs7rqdzdrrc6v_x7yc0000gn/T/ipykernel_89967/475419320.py in make_tax(adults, children)
#      22         dict(
#      23             employment_income=sim.calc("employment_income")[0],
# ---> 24             spm_unit_net_income=sim.calc("spm_unit_net_income")[0].round(),
#      25             mtr=-sim.deriv(
#      26                 "spm_unit_net_income", "employment_income", wrt_target="head"
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/hypothetical.py in calc(self, var, period, target, index, reform)
#     197                 result = self.sim.calculate_add(var, period)
#     198             except:
# --> 199                 result = self.simulation.calculate_divide(var, period)
#     200         if self.varying:
#     201             result = result.reshape(
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate_divide(self, variable_name, period)
#     189             return self.calculate(variable_name, period = computation_period) / 12.
#     190         elif period.unit == periods.YEAR:
# --> 191             return self.calculate(variable_name, period)
#     192
#     193         raise ValueError("Unable to divide the value of '{}' to match period {}.".format(
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/income/spm_unit/spm_unit_net_income.py in formula(spm_unit, period, parameters)
#      16             return reported_net_income
#      17         market_income = spm_unit("spm_unit_market_income", period)
# ---> 18         benefits = spm_unit("spm_unit_benefits", period)
#      19         taxes = spm_unit("spm_unit_taxes", period)
#      20         return market_income + benefits - taxes
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api.py in sum_of_variables(entity, period, parameters)
#     323         else:
#     324             variable_names = variables
# --> 325         return add(entity, period, variable_names)
#     326
#     327     return sum_of_variables
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api.py in add(entity, period, variables, options)
#     122     """
#     123     return for_each_variable(
# --> 124         entity, period, variables, agg_func="add", options=options
#     125     )
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#      84         variable_entity = entity.entity.get_variable(variable).entity
#      85         if variable_entity.key == entity.entity.key:
# ---> 86             values = entity(variable, period, options=options)
#      87         else:
#      88             try:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/snap.py in formula(spm_unit, period, parameters)
#      13     def formula(spm_unit, period, parameters):
#      14         ALLOTMENTS = ["snap_normal_allotment", "snap_emergency_allotment"]
# ---> 15         return add(spm_unit, period, ALLOTMENTS)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api.py in add(entity, period, variables, options)
#     122     """
#     123     return for_each_variable(
# --> 124         entity, period, variables, agg_func="add", options=options
#     125     )
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#      84         variable_entity = entity.entity.get_variable(variable).entity
#      85         if variable_entity.key == entity.entity.key:
# ---> 86             values = entity(variable, period, options=options)
#      87         else:
#      88             try:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/snap_normal_allotment.py in formula(spm_unit, period, parameters)
#      14         # Federal SNAP rules are defined in U.S.C Title 7, Chapter 51, which
#      15         # also defines state powers to modify the rules.
# ---> 16         eligible = spm_unit("is_snap_eligible", period)
#      17         expected_contribution = spm_unit("snap_expected_contribution", period)
#      18         max_allotment = spm_unit("snap_max_allotment", period)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/eligibility/is_snap_eligible.py in formula(spm_unit, period, parameters)
#      14
#      15     def formula(spm_unit, period, parameters):
# ---> 16         net = spm_unit("meets_snap_net_income_test", period)
#      17         gross = spm_unit("meets_snap_gross_income_test", period)
#      18         asset = spm_unit("meets_snap_asset_test", period)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/eligibility/meets_snap_net_income_test.py in formula(spm_unit, period, parameters)
#      15     def formula(spm_unit, period, parameters):
#      16         net_income_limit_fpg = parameters(period).usda.snap.income.limit.net
# ---> 17         net_income_fpg = spm_unit("snap_net_income_fpg_ratio", period)
#      18         return net_income_fpg <= net_income_limit_fpg
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     228
#     229         if formula.__code__.co_argcount == 2:
# --> 230             array = formula(population, period)
#     231         else:
#     232             array = formula(population, period, parameters_at)
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/income/snap_net_income_fpg_ratio.py in formula(spm_unit, period)
#      13
#      14     def formula(spm_unit, period):
# ---> 15         income = spm_unit("snap_net_income", period)
#      16         fpg = spm_unit("spm_unit_fpg", period)
#      17         return income / fpg
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     228
#     229         if formula.__code__.co_argcount == 2:
# --> 230             array = formula(population, period)
#     231         else:
#     232             array = formula(population, period, parameters_at)
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/income/snap_net_income.py in formula(spm_unit, period)
#      13     def formula(spm_unit, period):
#      14         gross_income = spm_unit("snap_gross_income", period)
# ---> 15         deductions = spm_unit("snap_deductions", period)
#      16         return max_(0, gross_income - deductions)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/income/deductions/snap_deductions.py in formula(spm_unit, period, parameters)
#      13     def formula(spm_unit, period, parameters):
#      14         snap_deductions = parameters(period).usda.snap.income.deductions
# ---> 15         return add(spm_unit, period, snap_deductions.allowed)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api.py in add(entity, period, variables, options)
#     122     """
#     123     return for_each_variable(
# --> 124         entity, period, variables, agg_func="add", options=options
#     125     )
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#      84         variable_entity = entity.entity.get_variable(variable).entity
#      85         if variable_entity.key == entity.entity.key:
# ---> 86             values = entity(variable, period, options=options)
#      87         else:
#      88             try:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/usda/snap/income/deductions/snap_excess_medical_expense_deduction.py in formula(spm_unit, period, parameters)
#      28         # Calculate standard medical deduction (SMD).
#      29         state = spm_unit.household("state_code_str", period)
# ---> 30         standard = p.standard[state] * 12
#      31         standard_claimable = where(excess > 0, standard, 0)
#      32         # Return the greater of SMD and normal deduction.
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/tracers/tracing_parameter_node_at_instant.py in __getitem__(self, key)
#      42             key: Union[str, ArrayLike],
#      43             ) -> Union[TracingParameterNodeAtInstant, Child]:
# ---> 44         child = self.parameter_node_at_instant[key]
#      45         return self.get_traced_child(child, key)
#      46
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/parameters/parameter_node_at_instant.py in __getitem__(self, key)
#      42         # If fancy indexing is used, cast to a vectorial node
#      43         if isinstance(key, numpy.ndarray):
# ---> 44             return parameters.VectorialParameterNodeAtInstant.build_from_node(self)[key]
#      45         return self._children[key]
#      46
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/parameters/vectorial_parameter_node_at_instant.py in __getitem__(self, key)
#     156                     key = key.astype('str')
#     157             names = list(self.dtype.names)  # Get all the names of the subnodes, e.g. ['zone_1', 'zone_2']
# --> 158             default = numpy.full_like(self.vector[key[0]], numpy.nan)  # In case of unexpected key, we will set the corresponding value to NaN.
#     159             conditions = [key == name for name in names]
#     160             values = [self.vector[name] for name in names]
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/numpy/core/records.py in __getitem__(self, indx)
#     517
#     518     def __getitem__(self, indx):
# --> 519         obj = super(recarray, self).__getitem__(indx)
#     520
#     521         # copy behavior of getattr, except that here
#
# ValueError: no field of name MA

# %% [markdown]
# Core marginal tax rates span from zero to five percent, but when including the EITC, they range from -13.5% to 12.3%, depending on income and household structure.

# %%
fig = px.line(
    df,
    "employment_income",
    "mtr",
    color="children",
    animation_frame="adults",
    labels=LABELS,
    title="Marginal tax rate for a Massachusetts household",
)
fig.update_layout(xaxis_tickformat="$,", yaxis_tickformat=".1%")
fig.show()
