# %% [markdown]
# # Massachusetts tax and benefit system
#
# This notebook shows how the state and federal tax and benefit system affects Massachusetts residents holistically.
#
# ## Examples
#
# Consider a set of Massachusetts family types, each with \$1,000 monthly rent and \$50 monthly broadband costs, and varying in terms of marital status and number of children.
# Their net income---after state and federal taxes and benefits modeled by OpenFisca US---is shown in the graph below.
#
# *The cliff is due to Massachusetts' emergency SNAP allotment, which entitles SNAP-eligible households to the maximum benefit for their household size; this also affects other benefits through categorical eligibility.*

# %%
from openfisca_us import IndividualSim
import pandas as pd
import plotly.express as px

LIGHT_GRAY = "#F5F5F5"
GRAY = "#BDBDBD"
BLUE = "#5091cc"
LIGHT_BLUE = "lightblue"
DARK_BLUE = "darkblue"


def make_tax(adults, children):
    sim = IndividualSim(year=2022)
    sim.add_person(name="head", age=25, rent=12_000)
    members = ["head"]
    if adults == 2:
        sim.add_person(name="spouse", age=25)
        members += ["spouse"]
    for i in range(children):
        child = "child{}".format(i)
        sim.add_person(name=child, age=6)
        members += [child]
    sim.add_tax_unit(name="tax_unit", members=members, premium_tax_credit=0)
    # $1,000 monthly rent, $50 monthly broadband.
    sim.add_spm_unit(name="spm_unit", members=members, broadband_cost=600)
    sim.add_household(name="household", members=members, state_code="MA")
    sim.vary("employment_income", max=100_000, step=100)
    employment_income = sim.calc("employment_income")[0]
    spm_unit_net_income = sim.calc("spm_unit_net_income")[0].round()
    mtr = 1 - sim.deriv(
        "spm_unit_net_income", "employment_income", wrt_target="head"
    )
    return pd.DataFrame(
        dict(
            employment_income=employment_income,
            spm_unit_net_income=spm_unit_net_income,
            mtr=mtr,
            adults=adults,
            children=str(children),
        )
    )


# Make a table of state taxes for different numbers of adults and children.
l = []
for adults in range(1, 3):
    for children in range(0, 4):
        l.append(make_tax(adults, children))

df = pd.concat(l)

LABELS = dict(
    employment_income="Employment income",
    spm_unit_net_income="Net income",
    mtr="Marginal tax rate",
    adults="Adults",
    children="Children",
)

COLOR_MAP = {"0": GRAY, "1": LIGHT_BLUE, "2": BLUE, "3": DARK_BLUE}

fig = px.line(
    df,
    "employment_income",
    "spm_unit_net_income",
    color="children",
    animation_frame="adults",
    labels=LABELS,
    title="Net income for a Massachusetts household",
    color_discrete_map=COLOR_MAP,
)
fig.update_layout(
    xaxis_tickformat="$,",
    yaxis_tickformat="$,",
    plot_bgcolor="white",
    xaxis_gridcolor=LIGHT_GRAY,
    yaxis_gridcolor=LIGHT_GRAY,
)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/hypothetical.py in calc(self, var, period, target, index, map_to, reform)
#     280         try:
# --> 281             result = self.simulation.calculate(var, period)
#     282         except:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/household/income/spm_unit/spm_unit_net_income.py in formula(spm_unit, period, parameters)
#      18         benefits = spm_unit("spm_unit_benefits", period)
# ---> 19         taxes = spm_unit("spm_unit_taxes", period)
#      20         return market_income + benefits - taxes
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in sum_of_variables(entity, period, parameters)
#     331             variable_names = variables
# --> 332         return add(entity, period, variable_names)
#     333
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in add(entity, period, variables, options)
#     130     return for_each_variable(
# --> 131         entity, period, variables, agg_func="add", options=options
#     132     )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#      85         if variable_entity.key == entity.entity.key:
# ---> 86             values = entity(variable, period, options=options)
#      87         elif variable_entity.is_person:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/household/expense/tax/spm_unit_federal_tax.py in formula(spm_unit, period, parameters)
#      11     def formula(spm_unit, period, parameters):
# ---> 12         return sum_contained_tax_units("income_tax", spm_unit, period)
#
# ~/PolicyEngine/openfisca-us/openfisca_us/tools/general.py in sum_contained_tax_units(var, population, period)
#      24     tax_unit = population.members.tax_unit.reference_entity
# ---> 25     values = tax_unit(var, period)
#      26     is_head = population.members("is_tax_unit_head", period)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     229         if formula.__code__.co_argcount == 2:
# --> 230             array = formula(population, period)
#     231         else:
#
# ~/PolicyEngine/openfisca-us/openfisca_us/tools/general.py in <lambda>(entity, period)
#      43     class_dict["formula"] = lambda entity, period: entity(
# ---> 44         variable_cls.__name__, period
#      45     )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/gov/irs/tax/federal_income/income_tax.py in formula(tax_unit, period, parameters)
#      13         before_refundable_credits = tax_unit(
# ---> 14             "income_tax_before_refundable_credits", period
#      15         )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/gov/irs/tax/federal_income/income_tax_before_refundable_credits.py in formula(tax_unit, period, parameters)
#      12     def formula(tax_unit, period, parameters):
# ---> 13         income_tax_bc = tax_unit("income_tax_before_credits", period)
#      14         capped_credits = tax_unit(
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     229         if formula.__code__.co_argcount == 2:
# --> 230             array = formula(population, period)
#     231         else:
#
# ~/PolicyEngine/openfisca-us/openfisca_us/tools/general.py in <lambda>(entity, period)
#      43     class_dict["formula"] = lambda entity, period: entity(
# ---> 44         variable_cls.__name__, period
#      45     )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in sum_of_variables(entity, period, parameters)
#     331             variable_names = variables
# --> 332         return add(entity, period, variable_names)
#     333
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in add(entity, period, variables, options)
#     130     return for_each_variable(
# --> 131         entity, period, variables, agg_func="add", options=options
#     132     )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#      85         if variable_entity.key == entity.entity.key:
# ---> 86             values = entity(variable, period, options=options)
#      87         elif variable_entity.is_person:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     229         if formula.__code__.co_argcount == 2:
# --> 230             array = formula(population, period)
#     231         else:
#
# ~/PolicyEngine/openfisca-us/openfisca_us/tools/general.py in <lambda>(entity, period)
#      43     class_dict["formula"] = lambda entity, period: entity(
# ---> 44         variable_cls.__name__, period
#      45     )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/gov/irs/tax/federal_income/before_credits/regular_tax_before_credits.py in formula(tax_unit, period, parameters)
#      14         filing_status = tax_unit("filing_status", period)
# ---> 15         dwks1 = tax_unit("taxable_income", period)
#      16
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/gov/irs/income/taxable_income/taxable_income.py in formula(tax_unit, period, parameters)
#      12         agi = tax_unit("adjusted_gross_income", period)
# ---> 13         deductions = tax_unit("taxable_income_deductions", period)
#      14         return max_(0, agi - deductions)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/gov/irs/income/taxable_income/deductions/taxable_income_deductions.py in formula(tax_unit, period, parameters)
#      11     def formula(tax_unit, period, parameters):
# ---> 12         itemizes = tax_unit("tax_unit_itemizes", period)
#      13         deductions_if_itemizing = tax_unit(
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/gov/irs/income/taxable_income/deductions/tax_unit_itemizes.py in formula(tax_unit, period, parameters)
#      12     def formula(tax_unit, period, parameters):
# ---> 13         tax_if_itemizing = tax_unit("tax_liability_if_itemizing", period)
#      14         tax_if_not_itemizing = tax_unit(
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/gov/irs/income/taxable_income/deductions/tax_liability_if_itemizing.py in formula(tax_unit, period, parameters)
#      21         values = simulation_if_itemizing.calculate(
# ---> 22             "federal_state_income_tax", period
#      23         )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in sum_of_variables(entity, period, parameters)
#     331             variable_names = variables
# --> 332         return add(entity, period, variable_names)
#     333
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in add(entity, period, variables, options)
#     130     return for_each_variable(
# --> 131         entity, period, variables, agg_func="add", options=options
#     132     )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#      85         if variable_entity.key == entity.entity.key:
# ---> 86             values = entity(variable, period, options=options)
#      87         elif variable_entity.is_person:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     229         if formula.__code__.co_argcount == 2:
# --> 230             array = formula(population, period)
#     231         else:
#
# ~/PolicyEngine/openfisca-us/openfisca_us/tools/general.py in <lambda>(entity, period)
#      43     class_dict["formula"] = lambda entity, period: entity(
# ---> 44         variable_cls.__name__, period
#      45     )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/gov/irs/tax/federal_income/income_tax.py in formula(tax_unit, period, parameters)
#      13         before_refundable_credits = tax_unit(
# ---> 14             "income_tax_before_refundable_credits", period
#      15         )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/gov/irs/tax/federal_income/income_tax_before_refundable_credits.py in formula(tax_unit, period, parameters)
#      12     def formula(tax_unit, period, parameters):
# ---> 13         income_tax_bc = tax_unit("income_tax_before_credits", period)
#      14         capped_credits = tax_unit(
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     229         if formula.__code__.co_argcount == 2:
# --> 230             array = formula(population, period)
#     231         else:
#
# ~/PolicyEngine/openfisca-us/openfisca_us/tools/general.py in <lambda>(entity, period)
#      43     class_dict["formula"] = lambda entity, period: entity(
# ---> 44         variable_cls.__name__, period
#      45     )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in sum_of_variables(entity, period, parameters)
#     331             variable_names = variables
# --> 332         return add(entity, period, variable_names)
#     333
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in add(entity, period, variables, options)
#     130     return for_each_variable(
# --> 131         entity, period, variables, agg_func="add", options=options
#     132     )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#      85         if variable_entity.key == entity.entity.key:
# ---> 86             values = entity(variable, period, options=options)
#      87         elif variable_entity.is_person:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     229         if formula.__code__.co_argcount == 2:
# --> 230             array = formula(population, period)
#     231         else:
#
# ~/PolicyEngine/openfisca-us/openfisca_us/tools/general.py in <lambda>(entity, period)
#      43     class_dict["formula"] = lambda entity, period: entity(
# ---> 44         variable_cls.__name__, period
#      45     )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/gov/irs/tax/federal_income/before_credits/regular_tax_before_credits.py in formula(tax_unit, period, parameters)
#      14         filing_status = tax_unit("filing_status", period)
# ---> 15         dwks1 = tax_unit("taxable_income", period)
#      16
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/gov/irs/income/taxable_income/taxable_income.py in formula(tax_unit, period, parameters)
#      12         agi = tax_unit("adjusted_gross_income", period)
# ---> 13         deductions = tax_unit("taxable_income_deductions", period)
#      14         return max_(0, agi - deductions)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/gov/irs/income/taxable_income/deductions/taxable_income_deductions.py in formula(tax_unit, period, parameters)
#      13         deductions_if_itemizing = tax_unit(
# ---> 14             "taxable_income_deductions_if_itemizing", period
#      15         )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in sum_of_variables(entity, period, parameters)
#     331             variable_names = variables
# --> 332         return add(entity, period, variable_names)
#     333
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in add(entity, period, variables, options)
#     130     return for_each_variable(
# --> 131         entity, period, variables, agg_func="add", options=options
#     132     )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#      85         if variable_entity.key == entity.entity.key:
# ---> 86             values = entity(variable, period, options=options)
#      87         elif variable_entity.is_person:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/gov/irs/income/taxable_income/deductions/itemizing/salt_deduction.py in formula(tax_unit, period, parameters)
#      16             period,
# ---> 17             ["state_and_local_sales_or_income_tax", "real_estate_taxes"],
#      18         )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in add(entity, period, variables, options)
#     130     return for_each_variable(
# --> 131         entity, period, variables, agg_func="add", options=options
#     132     )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#      85         if variable_entity.key == entity.entity.key:
# ---> 86             values = entity(variable, period, options=options)
#      87         elif variable_entity.is_person:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/gov/irs/taxcalc/deductions/itemized/state_and_local_sales_or_income_tax.py in formula(tax_unit, period, parameters)
#      13         income_tax = add(
# ---> 14             tax_unit, period, ["state_income_tax", "local_income_tax"]
#      15         )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in add(entity, period, variables, options)
#     130     return for_each_variable(
# --> 131         entity, period, variables, agg_func="add", options=options
#     132     )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#      85         if variable_entity.key == entity.entity.key:
# ---> 86             values = entity(variable, period, options=options)
#      87         elif variable_entity.is_person:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in sum_of_variables(entity, period, parameters)
#     331             variable_names = variables
# --> 332         return add(entity, period, variable_names)
#     333
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in add(entity, period, variables, options)
#     130     return for_each_variable(
# --> 131         entity, period, variables, agg_func="add", options=options
#     132     )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#      85         if variable_entity.key == entity.entity.key:
# ---> 86             values = entity(variable, period, options=options)
#      87         elif variable_entity.is_person:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/gov/states/md/tax/income/md_income_tax.py in formula(tax_unit, period, parameters)
#      13         tax_after_non_refundable_credits = tax_unit(
# ---> 14             "md_income_tax_after_non_refundable_credits", period
#      15         )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/gov/states/md/tax/income/md_income_tax_after_non_refundable_credits.py in formula(tax_unit, period, parameters)
#      11     def formula(tax_unit, period, parameters):
# ---> 12         tax_before_credits = tax_unit("md_income_tax_before_credits", period)
#      13         non_refundable_credits = tax_unit("md_non_refundable_credits", period)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/gov/states/md/tax/income/md_income_tax_before_credits.py in formula(tax_unit, period, parameters)
#      14         filing_statuses = filing_status.possible_values
# ---> 15         taxable_income = tax_unit("md_taxable_income", period)
#      16         p = parameters(period).gov.states.md.tax.income.rate_schedule
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ...
#      84         variable_entity = entity.entity.get_variable(variable).entity
#      85         if variable_entity.key == entity.entity.key:
# ---> 86             values = entity(variable, period, options=options)
#      87         elif variable_entity.is_person:
#      88             values = group_agg_func(
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/gov/irs/taxcalc/deductions/itemized/state_and_local_sales_or_income_tax.py in formula(tax_unit, period, parameters)
#      12         # Only sales or income tax can be itemized, but not both.
#      13         income_tax = add(
# ---> 14             tax_unit, period, ["state_income_tax", "local_income_tax"]
#      15         )
#      16         sales_tax = add(
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in add(entity, period, variables, options)
#     129     """
#     130     return for_each_variable(
# --> 131         entity, period, variables, agg_func="add", options=options
#     132     )
#     133
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#      84         variable_entity = entity.entity.get_variable(variable).entity
#      85         if variable_entity.key == entity.entity.key:
# ---> 86             values = entity(variable, period, options=options)
#      87         elif variable_entity.is_person:
#      88             values = group_agg_func(
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in sum_of_variables(entity, period, parameters)
#     330         else:
#     331             variable_names = variables
# --> 332         return add(entity, period, variable_names)
#     333
#     334     return sum_of_variables
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in add(entity, period, variables, options)
#     129     """
#     130     return for_each_variable(
# --> 131         entity, period, variables, agg_func="add", options=options
#     132     )
#     133
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#      84         variable_entity = entity.entity.get_variable(variable).entity
#      85         if variable_entity.key == entity.entity.key:
# ---> 86             values = entity(variable, period, options=options)
#      87         elif variable_entity.is_person:
#      88             values = group_agg_func(
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/gov/states/md/tax/income/md_income_tax.py in formula(tax_unit, period, parameters)
#      12         in_md = tax_unit.household("state_code_str", period) == "MD"
#      13         tax_after_non_refundable_credits = tax_unit(
# ---> 14             "md_income_tax_after_non_refundable_credits", period
#      15         )
#      16         refundable_credits = tax_unit("md_refundable_credits", period)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/gov/states/md/tax/income/md_income_tax_after_non_refundable_credits.py in formula(tax_unit, period, parameters)
#      10
#      11     def formula(tax_unit, period, parameters):
# ---> 12         tax_before_credits = tax_unit("md_income_tax_before_credits", period)
#      13         non_refundable_credits = tax_unit("md_non_refundable_credits", period)
#      14         return max_(0, tax_before_credits - non_refundable_credits)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/gov/states/md/tax/income/md_income_tax_before_credits.py in formula(tax_unit, period, parameters)
#      13         # Get possible values for filing_status
#      14         filing_statuses = filing_status.possible_values
# ---> 15         taxable_income = tax_unit("md_taxable_income", period)
#      16         p = parameters(period).gov.states.md.tax.income.rate_schedule
#      17         single_separate = p.single_separate.calc(taxable_income)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/gov/states/md/tax/income/md_taxable_income.py in formula(tax_unit, period, parameters)
#      12         md_agi = tax_unit("md_agi", period)
#      13         deductions_exemptions = add(
# ---> 14             tax_unit, period, ["md_deductions", "md_exemptions"]
#      15         )
#      16         return max_(0, md_agi - deductions_exemptions)
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in add(entity, period, variables, options)
#     129     """
#     130     return for_each_variable(
# --> 131         entity, period, variables, agg_func="add", options=options
#     132     )
#     133
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_tools/model_api/model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#      84         variable_entity = entity.entity.get_variable(variable).entity
#      85         if variable_entity.key == entity.entity.key:
# ---> 86             values = entity(variable, period, options=options)
#      87         elif variable_entity.is_person:
#      88             values = group_agg_func(
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# ~/PolicyEngine/openfisca-us/openfisca_us/variables/gov/states/md/tax/income/deductions/md_deductions.py in formula(tax_unit, period, parameters)
#      15         standard_deduction = tax_unit("md_standard_deduction", period)
#      16         federal_deductions_if_itemizing = tax_unit_itemizes * tax_unit(
# ---> 17             "taxable_income_deductions_if_itemizing", period
#      18         )
#      19         salt = tax_unit("salt_deduction", period)
#
# ... last 55 frames repeated, from the frame below ...
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# Total marginal tax rates range from below -50% to above 50%.

# %%
fig = px.line(
    df,
    "employment_income",
    "mtr",
    color="children",
    animation_frame="adults",
    labels=LABELS,
    title="Marginal tax rate for a Massachusetts household",
    color_discrete_map=COLOR_MAP,
)
fig.update_layout(
    xaxis_tickformat="$,",
    yaxis_tickformat=".1%",
    yaxis_range=[-1, 1],
    plot_bgcolor="white",
    xaxis_gridcolor=LIGHT_GRAY,
    yaxis_gridcolor=LIGHT_GRAY,
)
fig.show()

# %% [markdown]
# ### Other situations
#
# A single person who is age 65 and holds less than \$2,000 in assets will be eligible for additional tax exemptions and federal Supplemental Security Income (SSI).

# %%
sim = IndividualSim(year=2022)
sim.add_person(name="head", age=65)
sim.add_tax_unit(name="tax_unit", members=["head"], premium_tax_credit=0)
sim.add_spm_unit(name="spmu", members=["head"])
sim.add_household(name="h", members=["head"], state_code="MA")

sim.vary("employment_income", max=100_000, step=100)
employment_income = sim.calc("employment_income")[0]
spm_unit_net_income = sim.calc("spm_unit_net_income")[0].round()
mtr = 1 - sim.deriv(
    "spm_unit_net_income", "employment_income", wrt_target="head"
)
df = pd.DataFrame(
    dict(
        employment_income=employment_income,
        spm_unit_net_income=spm_unit_net_income,
        mtr=mtr,
    )
)

fig = px.line(
    df,
    "employment_income",
    "spm_unit_net_income",
    labels=LABELS,
    title="Net income for a single person aged 65 in Massachusetts",
)

fig.update_layout(
    xaxis_tickformat="$,",
    yaxis_tickformat="$,",
    plot_bgcolor="white",
    xaxis_gridcolor=LIGHT_GRAY,
    yaxis_gridcolor=LIGHT_GRAY,
)
fig.show()

# %% [markdown]
# This single 65-year-old faces marginal tax rates between 57 and 80 percent when they earn between \$1,100 and \$21,300.
# Earnings beyond that, up to \$100,000, are subject to marginal tax rates between 22 and 35 percent, except for a cliff when they lose SNAP eligibility at \$25,700 earnings.

# %%
fig = px.line(
    df,
    "employment_income",
    "mtr",
    labels=LABELS,
    title="Marginal tax rate for a single person aged 65 in Massachusetts",
)

fig.update_layout(
    xaxis_tickformat="$,",
    yaxis_tickformat=".1%",
    yaxis_range=[0, 1],
    plot_bgcolor="white",
    xaxis_gridcolor=LIGHT_GRAY,
    yaxis_gridcolor=LIGHT_GRAY,
)
fig.show()
