# %% [markdown]
# # Oregon state income tax
#
# This notebook shows how Oregon's state income tax, including credits, operates holistically.
#
# ## Examples

# %%
from openfisca_us import IndividualSim
import pandas as pd
import plotly.express as px

LIGHT_GRAY = "#F5F5F5"
GRAY = "#BDBDBD"
BLUE = "#5091cc"
LIGHT_BLUE = "lightblue"
DARK_BLUE = "darkblue"


def make_tax(adults, children):
    sim = IndividualSim(year=2022)
    sim.add_person(name="head", age=25)
    members = ["head"]
    if adults == 2:
        sim.add_person(name="spouse", age=25)
        members += ["spouse"]
    for i in range(children):
        child = "child{}".format(i)
        sim.add_person(name=child, age=6)
        members += [child]
    sim.add_tax_unit(name="tax_unit", members=members, premium_tax_credit=0)
    sim.add_household(name="household", members=members, state_code="OR")
    sim.vary("employment_income", max=100_000, step=100)
    employment_income = sim.calc("employment_income")[0]
    state_income_tax = sim.calc("state_income_tax")[0].round()
    mtr = sim.deriv("state_income_tax", "employment_income", wrt_target="head")
    return pd.DataFrame(
        dict(
            employment_income=employment_income,
            state_income_tax=state_income_tax,
            mtr=mtr,
            adults=adults,
            children=str(children),
        )
    )


# Make a table of state taxes for different numbers of adults and children.
l = []
for adults in range(1, 3):
    for children in range(0, 4):
        l.append(make_tax(adults, children))

df = pd.concat(l)

LABELS = dict(
    employment_income="Employment income",
    state_income_tax="Oregon tax",
    mtr="Marginal tax rate",
    adults="Adults",
    children="Children",
)

COLOR_MAP = {"0": GRAY, "1": LIGHT_BLUE, "2": BLUE, "3": DARK_BLUE}

fig = px.line(
    df,
    "employment_income",
    "state_income_tax",
    color="children",
    animation_frame="adults",
    labels=LABELS,
    title="Oregon state income tax",
    color_discrete_map=COLOR_MAP,
)
fig.update_layout(
    xaxis_tickformat="$,",
    yaxis_tickformat="$,",
    plot_bgcolor="white",
    xaxis_gridcolor=LIGHT_GRAY,
    yaxis_gridcolor=LIGHT_GRAY,
)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\hypothetical.py in calc(self, var, period, target, index, map_to, reform)
#     280         try:
# --> 281             result = self.simulation.calculate(var, period)
#     282         except:
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in sum_of_variables(entity, period, parameters)
#     350             variable_names = variables
# --> 351         return add(entity, period, variable_names)
#     352
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in add(entity, period, variables, options)
#     149     return for_each_variable(
# --> 150         entity, period, variables, agg_func="add", options=options
#     151     )
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     104         if variable_entity.key == entity.entity.key:
# --> 105             values = entity(variable, period, options=options)
#     106         elif variable_entity.is_person:
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\states\or\tax\income\or_income_tax_after_refundable_credits.py in formula(tax_unit, period, parameters)
#      11     def formula(tax_unit, period, parameters):
# ---> 12         income_tax_after_non_refundable_credits = tax_unit("or_income_tax_after_non_refundable_credits", period)
#      13         refundable_credits = tax_unit("or_refundable_credits", period)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\states\or\tax\income\or_income_tax_after_non_refundable_credits.py in formula(tax_unit, period, parameters)
#      17     def formula(tax_unit, period, parameters):
# ---> 18         income_tax_before_credits = tax_unit("or_income_tax_before_credits", period)
#      19         non_refundable_credits = tax_unit("or_non_refundable_credits", period)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\defined_for.py in partially_executed_formula(entity, period, parameters)
#      95
# ---> 96         formula_result = formula(subset_entity, period, parameters)
#      97         formula_result = np.array(formula_result)
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\states\or\tax\income\or_income_tax_before_credits.py in formula(tax_unit, period, parameters)
#      18         statuses = filing_status.possible_values
# ---> 19         income = tax_unit("or_taxable_income", period)
#      20         rates = parameters(period).gov.states["or"].tax.income.rates
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\defined_for.py in __call__(self, *args, **kwargs)
#      43     def __call__(self, *args, **kwargs):
# ---> 44         return self.population(*args, **kwargs)[self.mask]
#      45
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\defined_for.py in partially_executed_formula(entity, period, parameters)
#      95
# ---> 96         formula_result = formula(subset_entity, period, parameters)
#      97         formula_result = np.array(formula_result)
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\states\or\tax\income\or_taxable_income.py in formula(tax_unit, period, parameters)
#      13         income_after_subtractions = tax_unit(
# ---> 14             "or_income_after_subtractions", period
#      15         )
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\defined_for.py in __call__(self, *args, **kwargs)
#      43     def __call__(self, *args, **kwargs):
# ---> 44         return self.population(*args, **kwargs)[self.mask]
#      45
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\defined_for.py in partially_executed_formula(entity, period, parameters)
#      95
# ---> 96         formula_result = formula(subset_entity, period, parameters)
#      97         formula_result = np.array(formula_result)
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\states\or\tax\income\or_income_after_subtractions.py in formula(tax_unit, period, parameters)
#      13         income_after_additions = tax_unit("or_income_after_additions", period)
# ---> 14         subtractions = tax_unit("or_income_subtractions", period)
#      15         return income_after_additions - subtractions
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\defined_for.py in __call__(self, *args, **kwargs)
#      43     def __call__(self, *args, **kwargs):
# ---> 44         return self.population(*args, **kwargs)[self.mask]
#      45
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\defined_for.py in partially_executed_formula(entity, period, parameters)
#      95
# ---> 96         formula_result = formula(subset_entity, period, parameters)
#      97         formula_result = np.array(formula_result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in sum_of_variables(entity, period, parameters)
#     350             variable_names = variables
# --> 351         return add(entity, period, variable_names)
#     352
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in add(entity, period, variables, options)
#     149     return for_each_variable(
# --> 150         entity, period, variables, agg_func="add", options=options
#     151     )
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     104         if variable_entity.key == entity.entity.key:
# --> 105             values = entity(variable, period, options=options)
#     106         elif variable_entity.is_person:
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\defined_for.py in __call__(self, *args, **kwargs)
#      43     def __call__(self, *args, **kwargs):
# ---> 44         return self.population(*args, **kwargs)[self.mask]
#      45
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\defined_for.py in partially_executed_formula(entity, period, parameters)
#      95
# ---> 96         formula_result = formula(subset_entity, period, parameters)
#      97         formula_result = np.array(formula_result)
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\states\or\tax\income\subtractions\or_federal_tax_liability_subtraction.py in formula(tax_unit, period, parameters)
#      21         # withholding rules.
# ---> 22         federal_tax_liability = tax_unit("no_salt_income_tax", period)
#      23         # Instructions for line 14:
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\defined_for.py in __call__(self, *args, **kwargs)
#      43     def __call__(self, *args, **kwargs):
# ---> 44         return self.population(*args, **kwargs)[self.mask]
#      45
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\irs\tax\federal_income\no_salt_income_tax.py in formula(tax_unit, period, parameters)
#      18             ]  # This is needed because neutralize_variable is only designed to work *before* simulations have started.
# ---> 19             tax_liability = simulation.calculate("income_tax", period)
#      20             simulation.get_holder(
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     229         if formula.__code__.co_argcount == 2:
# --> 230             array = formula(population, period)
#     231         else:
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\tools\general.py in <lambda>(entity, period)
#      46     class_dict["formula"] = lambda entity, period: entity(
# ---> 47         variable_cls.__name__, period
#      48     )
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\irs\tax\federal_income\income_tax.py in formula(tax_unit, period, parameters)
#      13         before_refundable_credits = tax_unit(
# ---> 14             "income_tax_before_refundable_credits", period
#      15         )
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\irs\tax\federal_income\income_tax_before_refundable_credits.py in formula(tax_unit, period, parameters)
#      12     def formula(tax_unit, period, parameters):
# ---> 13         income_tax_bc = tax_unit("income_tax_before_credits", period)
#      14         capped_credits = tax_unit(
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     229         if formula.__code__.co_argcount == 2:
# --> 230             array = formula(population, period)
#     231         else:
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\tools\general.py in <lambda>(entity, period)
#      46     class_dict["formula"] = lambda entity, period: entity(
# ---> 47         variable_cls.__name__, period
#      48     )
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in sum_of_variables(entity, period, parameters)
#     350             variable_names = variables
# --> 351         return add(entity, period, variable_names)
#     352
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in add(entity, period, variables, options)
#     149     return for_each_variable(
# --> 150         entity, period, variables, agg_func="add", options=options
#     151     )
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     104         if variable_entity.key == entity.entity.key:
# --> 105             values = entity(variable, period, options=options)
#     106         elif variable_entity.is_person:
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     229         if formula.__code__.co_argcount == 2:
# --> 230             array = formula(population, period)
#     231         else:
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\tools\general.py in <lambda>(entity, period)
#      46     class_dict["formula"] = lambda entity, period: entity(
# ---> 47         variable_cls.__name__, period
#      48     )
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\irs\tax\federal_income\before_credits\income_tax_main_rates.py in formula(tax_unit, period, parameters)
#      24         pt_taxinc = max_(0, pt_active)
# ---> 25         full_taxable_income = tax_unit("taxable_income", period)
#      26
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\irs\income\taxable_income\taxable_income.py in formula(tax_unit, period, parameters)
#      12         agi = tax_unit("adjusted_gross_income", period)
# ---> 13         deductions = tax_unit("taxable_income_deductions", period)
#      14         return max_(0, agi - deductions)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\irs\income\taxable_income\deductions\taxable_income_deductions.py in formula(tax_unit, period, parameters)
#      11     def formula(tax_unit, period, parameters):
# ---> 12         itemizes = tax_unit("tax_unit_itemizes", period)
#      13         deductions_if_itemizing = tax_unit(
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\irs\income\taxable_income\deductions\tax_unit_itemizes.py in formula(tax_unit, period, parameters)
#      12     def formula(tax_unit, period, parameters):
# ---> 13         tax_if_itemizing = tax_unit("tax_liability_if_itemizing", period)
#      14         tax_if_not_itemizing = tax_unit(
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\irs\income\taxable_income\deductions\tax_liability_if_itemizing.py in formula(tax_unit, period, parameters)
#      18             values = simulation_if_itemizing.calculate(
# ---> 19                 "federal_state_income_tax", period
#      20             )
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in sum_of_variables(entity, period, parameters)
#     350             variable_names = variables
# --> 351         return add(entity, period, variable_names)
#     352
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in add(entity, period, variables, options)
#     149     return for_each_variable(
# --> 150         entity, period, variables, agg_func="add", options=options
#     151     )
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     104         if variable_entity.key == entity.entity.key:
# --> 105             values = entity(variable, period, options=options)
#     106         elif variable_entity.is_person:
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in sum_of_variables(entity, period, parameters)
#     350             variable_names = variables
# --> 351         return add(entity, period, variable_names)
#     352
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in add(entity, period, variables, options)
#     149     return for_each_variable(
# --> 150         entity, period, variables, agg_func="add", options=options
#     151     )
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     104         if variable_entity.key == entity.entity.key:
# --> 105             values = entity(variable, period, options=options)
#     106         elif variable_entity.is_person:
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\states\or\tax\income\or_income_tax_after_refundable_credits.py in formula(tax_unit, period, parameters)
#      12         income_tax_after_non_refundable_credits = tax_unit("or_income_tax_after_non_refundable_credits", period)
# ---> 13         refundable_credits = tax_unit("or_refundable_credits", period)
#      14         return income_tax_after_non_refundable_credits - refundable_credits
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in sum_of_variables(entity, period, parameters)
#     350             variable_names = variables
# --> 351         return add(entity, period, variable_names)
#     352
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in add(entity, period, variables, options)
#     149     return for_each_variable(
# --> 150         entity, period, variables, agg_func="add", options=options
#     151     )
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     102     for variable in variables:
# --> 103         variable_entity = entity.entity.get_variable(variable).entity
#     104         if variable_entity.key == entity.entity.key:
#
# AttributeError: 'NoneType' object has no attribute 'entity'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\hypothetical.py in calc(self, var, period, target, index, map_to, reform)
#     283             try:
# --> 284                 result = self.sim.calculate_add(var, period)
#     285             except:
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate_add(self, variable_name, period)
#     168             self.calculate(variable_name, sub_period)
# --> 169             for sub_period in period.get_subperiods(variable.definition_period)
#     170             )
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in <genexpr>(.0)
#     168             self.calculate(variable_name, sub_period)
# --> 169             for sub_period in period.get_subperiods(variable.definition_period)
#     170             )
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in sum_of_variables(entity, period, parameters)
#     350             variable_names = variables
# --> 351         return add(entity, period, variable_names)
#     352
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in add(entity, period, variables, options)
#     149     return for_each_variable(
# --> 150         entity, period, variables, agg_func="add", options=options
#     151     )
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     104         if variable_entity.key == entity.entity.key:
# --> 105             values = entity(variable, period, options=options)
#     106         elif variable_entity.is_person:
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\states\or\tax\income\or_income_tax_after_refundable_credits.py in formula(tax_unit, period, parameters)
#      11     def formula(tax_unit, period, parameters):
# ---> 12         income_tax_after_non_refundable_credits = tax_unit("or_income_tax_after_non_refundable_credits", period)
#      13         refundable_credits = tax_unit("or_refundable_credits", period)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\states\or\tax\income\or_income_tax_after_non_refundable_credits.py in formula(tax_unit, period, parameters)
#      17     def formula(tax_unit, period, parameters):
# ---> 18         income_tax_before_credits = tax_unit("or_income_tax_before_credits", period)
#      19         non_refundable_credits = tax_unit("or_non_refundable_credits", period)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\defined_for.py in partially_executed_formula(entity, period, parameters)
#      95
# ---> 96         formula_result = formula(subset_entity, period, parameters)
#      97         formula_result = np.array(formula_result)
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\states\or\tax\income\or_income_tax_before_credits.py in formula(tax_unit, period, parameters)
#      18         statuses = filing_status.possible_values
# ---> 19         income = tax_unit("or_taxable_income", period)
#      20         rates = parameters(period).gov.states["or"].tax.income.rates
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\defined_for.py in __call__(self, *args, **kwargs)
#      43     def __call__(self, *args, **kwargs):
# ---> 44         return self.population(*args, **kwargs)[self.mask]
#      45
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\defined_for.py in partially_executed_formula(entity, period, parameters)
#      95
# ---> 96         formula_result = formula(subset_entity, period, parameters)
#      97         formula_result = np.array(formula_result)
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\states\or\tax\income\or_taxable_income.py in formula(tax_unit, period, parameters)
#      13         income_after_subtractions = tax_unit(
# ---> 14             "or_income_after_subtractions", period
#      15         )
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\defined_for.py in __call__(self, *args, **kwargs)
#      43     def __call__(self, *args, **kwargs):
# ---> 44         return self.population(*args, **kwargs)[self.mask]
# ...
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\irs\income\taxable_income\taxable_income.py in formula(tax_unit, period, parameters)
#      11     def formula(tax_unit, period, parameters):
#      12         agi = tax_unit("adjusted_gross_income", period)
# ---> 13         deductions = tax_unit("taxable_income_deductions", period)
#      14         return max_(0, agi - deductions)
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\irs\income\taxable_income\deductions\taxable_income_deductions.py in formula(tax_unit, period, parameters)
#      10
#      11     def formula(tax_unit, period, parameters):
# ---> 12         itemizes = tax_unit("tax_unit_itemizes", period)
#      13         deductions_if_itemizing = tax_unit(
#      14             "taxable_income_deductions_if_itemizing", period
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\irs\income\taxable_income\deductions\tax_unit_itemizes.py in formula(tax_unit, period, parameters)
#      11
#      12     def formula(tax_unit, period, parameters):
# ---> 13         tax_if_itemizing = tax_unit("tax_liability_if_itemizing", period)
#      14         tax_if_not_itemizing = tax_unit(
#      15             "tax_liability_if_not_itemizing", period
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\irs\income\taxable_income\deductions\tax_liability_if_itemizing.py in formula(tax_unit, period, parameters)
#      17             )
#      18             values = simulation_if_itemizing.calculate(
# ---> 19                 "federal_state_income_tax", period
#      20             )
#      21         return values
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in sum_of_variables(entity, period, parameters)
#     349         else:
#     350             variable_names = variables
# --> 351         return add(entity, period, variable_names)
#     352
#     353     return sum_of_variables
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in add(entity, period, variables, options)
#     148     """
#     149     return for_each_variable(
# --> 150         entity, period, variables, agg_func="add", options=options
#     151     )
#     152
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     103         variable_entity = entity.entity.get_variable(variable).entity
#     104         if variable_entity.key == entity.entity.key:
# --> 105             values = entity(variable, period, options=options)
#     106         elif variable_entity.is_person:
#     107             values = group_agg_func(
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in sum_of_variables(entity, period, parameters)
#     349         else:
#     350             variable_names = variables
# --> 351         return add(entity, period, variable_names)
#     352
#     353     return sum_of_variables
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in add(entity, period, variables, options)
#     148     """
#     149     return for_each_variable(
# --> 150         entity, period, variables, agg_func="add", options=options
#     151     )
#     152
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     103         variable_entity = entity.entity.get_variable(variable).entity
#     104         if variable_entity.key == entity.entity.key:
# --> 105             values = entity(variable, period, options=options)
#     106         elif variable_entity.is_person:
#     107             values = group_agg_func(
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# c:\users\kevin\documents\openfisca-us\openfisca_us\variables\gov\states\or\tax\income\or_income_tax_after_refundable_credits.py in formula(tax_unit, period, parameters)
#      11     def formula(tax_unit, period, parameters):
#      12         income_tax_after_non_refundable_credits = tax_unit("or_income_tax_after_non_refundable_credits", period)
# ---> 13         refundable_credits = tax_unit("or_refundable_credits", period)
#      14         return income_tax_after_non_refundable_credits - refundable_credits
#      15
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\populations\population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_core\simulations\simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in sum_of_variables(entity, period, parameters)
#     349         else:
#     350             variable_names = variables
# --> 351         return add(entity, period, variable_names)
#     352
#     353     return sum_of_variables
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in add(entity, period, variables, options)
#     148     """
#     149     return for_each_variable(
# --> 150         entity, period, variables, agg_func="add", options=options
#     151     )
#     152
#
# c:\Users\Kevin\miniconda3\lib\site-packages\openfisca_tools\model_api\model_api.py in for_each_variable(entity, period, variables, agg_func, group_agg_func, options)
#     101         )[group_agg_func]
#     102     for variable in variables:
# --> 103         variable_entity = entity.entity.get_variable(variable).entity
#     104         if variable_entity.key == entity.entity.key:
#     105             values = entity(variable, period, options=options)
#
# AttributeError: 'NoneType' object has no attribute 'entity'

# %% [markdown]
# Total marginal tax rates range from -20.3% to +15.3%, excluding cliffs.

# %%
fig = px.line(
    df,
    "employment_income",
    "mtr",
    color="children",
    animation_frame="adults",
    labels=LABELS,
    title="Marginal tax rate for a New York household",
    color_discrete_map=COLOR_MAP,
)
fig.update_layout(
    xaxis_tickformat="$,",
    yaxis_tickformat=".1%",
    yaxis_range=[-0.2, 0.2],
    plot_bgcolor="white",
    xaxis_gridcolor=LIGHT_GRAY,
    yaxis_gridcolor=LIGHT_GRAY,
)
fig.show()
