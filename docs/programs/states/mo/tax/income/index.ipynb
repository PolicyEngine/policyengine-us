# %%
from openfisca_us import IndividualSim
import pandas as pd
import plotly.express as px

LIGHT_GRAY = "#F5F5F5"
GRAY = "#BDBDBD"
BLUE = "#5091cc"
LIGHT_BLUE = "lightblue"
DARK_BLUE = "darkblue"


def make_tax(adults, children):
    sim = IndividualSim(year=2022)
    sim.add_person(name="head", age=25)
    members = ["head"]
    if adults == 2:
        sim.add_person(name="spouse", age=25)
        members += ["spouse"]
    for i in range(children):
        child = "child{}".format(i)
        sim.add_person(name=child, age=6)
        members += [child]
    sim.add_tax_unit(name="tax_unit", members=members, premium_tax_credit=0)
    sim.add_household(name="household", members=members, state_code="MO")
    sim.vary("employment_income", max=100_000, step=100)
    employment_income = sim.calc("employment_income")[0]
    mo_income_tax = sim.calc("mo_income_tax")[0].round()
    mtr = sim.deriv("mo_income_tax", "employment_income", wrt_target="head")
    return pd.DataFrame(
        dict(
            employment_income=employment_income,
            mo_income_tax=mo_income_tax,
            mtr=mtr,
            adults=adults,
            children=str(children),
        )
    )


# Make a table of state taxes for different numbers of adults and children.
l = []
for adults in range(1, 3):
    for children in range(0, 4):
        l.append(make_tax(adults, children))

df = pd.concat(l)

LABELS = dict(
    employment_income="Employment income",
    mo_income_tax="Missouri income tax",
    mtr="Marginal tax rate",
    adults="Adults",
    children="Children",
)

COLOR_MAP = {"0": GRAY, "1": LIGHT_BLUE, "2": BLUE, "3": DARK_BLUE}

fig = px.line(
    df,
    "employment_income",
    "mo_income_tax",
    color="children",
    animation_frame="adults",
    labels=LABELS,
    title="Missouri income tax",
    color_discrete_map=COLOR_MAP,
)
fig.update_layout(
    xaxis_tickformat="$,",
    yaxis_tickformat="$,",
    plot_bgcolor="white",
    xaxis_gridcolor=LIGHT_GRAY,
    yaxis_gridcolor=LIGHT_GRAY,
)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/hypothetical.py in calc(self, var, period, target, index, map_to, reform)
#     280         try:
# --> 281             result = self.simulation.calculate(var, period)
#     282         except:
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in partially_executed_formula(entity, period, parameters)
#      76
# ---> 77         formula_result = formula(subset_entity, period, parameters)
#      78         formula_result = np.array(formula_result)
#
# ~/policyengine/openfisca-us/openfisca_us/variables/gov/states/mo/tax/income/income_tax/mo_income_tax.py in formula(tax_unit, period, parameters)
#      19         mo_income_tax_before_credits = tax_unit(
# ---> 20             "mo_income_tax_before_credits", period
#      21         )
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in __call__(self, *args, **kwargs)
#      24     def __call__(self, *args, **kwargs):
# ---> 25         return self.population(*args, **kwargs)[self.mask]
#      26
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in partially_executed_formula(entity, period, parameters)
#      76
# ---> 77         formula_result = formula(subset_entity, period, parameters)
#      78         formula_result = np.array(formula_result)
#
# ~/policyengine/openfisca-us/openfisca_us/variables/gov/states/mo/tax/income/income_tax/mo_income_tax_before_credits.py in formula(tax_unit, period, parameters)
#      16     def formula(tax_unit, period, parameters):
# ---> 17         taxable_income = tax_unit("mo_taxable_income", period)
#      18         rates = parameters(period).gov.states.mo.tax.income.rates
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in __call__(self, *args, **kwargs)
#      24     def __call__(self, *args, **kwargs):
# ---> 25         return self.population(*args, **kwargs)[self.mask]
#      26
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in partially_executed_formula(entity, period, parameters)
#      76
# ---> 77         formula_result = formula(subset_entity, period, parameters)
#      78         formula_result = np.array(formula_result)
#
# ~/policyengine/openfisca-us/openfisca_us/variables/gov/states/mo/tax/income/taxable_income/mo_taxable_income.py in formula(tax_unit, period, parameters)
#      18
# ---> 19         mo_agi = tax_unit("mo_adjusted_gross_income", period)
#      20         mo_federal_income_tax_deduction = tax_unit(
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in __call__(self, *args, **kwargs)
#      24     def __call__(self, *args, **kwargs):
# ---> 25         return self.population(*args, **kwargs)[self.mask]
#      26
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in partially_executed_formula(entity, period, parameters)
#      76
# ---> 77         formula_result = formula(subset_entity, period, parameters)
#      78         formula_result = np.array(formula_result)
#
# ~/policyengine/openfisca-us/openfisca_us/variables/gov/states/mo/tax/income/adjusted_gross_income/mo_adjusted_gross_income.py in formula(tax_unit, period, parameters)
#      18         subtractions = tax_unit(
# ---> 19             "mo_qualified_health_insurance_premiums", period
#      20         )
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in __call__(self, *args, **kwargs)
#      24     def __call__(self, *args, **kwargs):
# ---> 25         return self.population(*args, **kwargs)[self.mask]
#      26
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in partially_executed_formula(entity, period, parameters)
#      76
# ---> 77         formula_result = formula(subset_entity, period, parameters)
#      78         formula_result = np.array(formula_result)
#
# ~/policyengine/openfisca-us/openfisca_us/variables/gov/states/mo/tax/income/subtractions/mo_qualified_health_insurance_premiums.py in formula(tax_unit, period, parameters)
#      38                 med_expense_deduction
# ---> 39                 / (med_dental_out_of_pocket + total_health_insurance_premiums)
#      40             ),
#
# ValueError: operands could not be broadcast together with shapes (1001,) (2002,)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/hypothetical.py in calc(self, var, period, target, index, map_to, reform)
#     283             try:
# --> 284                 result = self.sim.calculate_add(var, period)
#     285             except:
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate_add(self, variable_name, period)
#     168             self.calculate(variable_name, sub_period)
# --> 169             for sub_period in period.get_subperiods(variable.definition_period)
#     170             )
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in <genexpr>(.0)
#     168             self.calculate(variable_name, sub_period)
# --> 169             for sub_period in period.get_subperiods(variable.definition_period)
#     170             )
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in partially_executed_formula(entity, period, parameters)
#      76
# ---> 77         formula_result = formula(subset_entity, period, parameters)
#      78         formula_result = np.array(formula_result)
#
# ~/policyengine/openfisca-us/openfisca_us/variables/gov/states/mo/tax/income/income_tax/mo_income_tax.py in formula(tax_unit, period, parameters)
#      19         mo_income_tax_before_credits = tax_unit(
# ---> 20             "mo_income_tax_before_credits", period
#      21         )
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in __call__(self, *args, **kwargs)
#      24     def __call__(self, *args, **kwargs):
# ---> 25         return self.population(*args, **kwargs)[self.mask]
#      26
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in partially_executed_formula(entity, period, parameters)
#      76
# ---> 77         formula_result = formula(subset_entity, period, parameters)
#      78         formula_result = np.array(formula_result)
#
# ~/policyengine/openfisca-us/openfisca_us/variables/gov/states/mo/tax/income/income_tax/mo_income_tax_before_credits.py in formula(tax_unit, period, parameters)
#      16     def formula(tax_unit, period, parameters):
# ---> 17         taxable_income = tax_unit("mo_taxable_income", period)
#      18         rates = parameters(period).gov.states.mo.tax.income.rates
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in __call__(self, *args, **kwargs)
#      24     def __call__(self, *args, **kwargs):
# ---> 25         return self.population(*args, **kwargs)[self.mask]
#      26
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in partially_executed_formula(entity, period, parameters)
#      76
# ---> 77         formula_result = formula(subset_entity, period, parameters)
#      78         formula_result = np.array(formula_result)
#
# ~/policyengine/openfisca-us/openfisca_us/variables/gov/states/mo/tax/income/taxable_income/mo_taxable_income.py in formula(tax_unit, period, parameters)
#      18
# ---> 19         mo_agi = tax_unit("mo_adjusted_gross_income", period)
#      20         mo_federal_income_tax_deduction = tax_unit(
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in __call__(self, *args, **kwargs)
#      24     def __call__(self, *args, **kwargs):
# ---> 25         return self.population(*args, **kwargs)[self.mask]
#      26
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in partially_executed_formula(entity, period, parameters)
#      76
# ---> 77         formula_result = formula(subset_entity, period, parameters)
#      78         formula_result = np.array(formula_result)
#
# ~/policyengine/openfisca-us/openfisca_us/variables/gov/states/mo/tax/income/adjusted_gross_income/mo_adjusted_gross_income.py in formula(tax_unit, period, parameters)
#      18         subtractions = tax_unit(
# ---> 19             "mo_qualified_health_insurance_premiums", period
#      20         )
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in __call__(self, *args, **kwargs)
#      24     def __call__(self, *args, **kwargs):
# ---> 25         return self.population(*args, **kwargs)[self.mask]
#      26
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in partially_executed_formula(entity, period, parameters)
#      76
# ---> 77         formula_result = formula(subset_entity, period, parameters)
#      78         formula_result = np.array(formula_result)
#
# ~/policyengine/openfisca-us/openfisca_us/variables/gov/states/mo/tax/income/subtractions/mo_qualified_health_insurance_premiums.py in formula(tax_unit, period, parameters)
#      38                 med_expense_deduction
# ---> 39                 / (med_dental_out_of_pocket + total_health_insurance_premiums)
#      40             ),
#
# ValueError: operands could not be broadcast together with shapes (1001,) (2002,)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/j9/k7nsyjk10yg90pwt82hlltbc0000gn/T/ipykernel_1362/2090487659.py in <module>
#      42 for adults in range(1, 3):
#      43     for children in range(0, 4):
# ---> 44         l.append(make_tax(adults, children))
#      45
#      46 df = pd.concat(l)
#
# /var/folders/j9/k7nsyjk10yg90pwt82hlltbc0000gn/T/ipykernel_1362/2090487659.py in make_tax(adults, children)
#      25     sim.vary("employment_income", max=100_000, step=100)
#      26     employment_income = sim.calc("employment_income")[0]
# ---> 27     mo_income_tax = sim.calc("mo_income_tax")[0].round()
#      28     mtr = sim.deriv("mo_income_tax", "employment_income", wrt_target="head")
#      29     return pd.DataFrame(
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/hypothetical.py in calc(self, var, period, target, index, map_to, reform)
#     284                 result = self.sim.calculate_add(var, period)
#     285             except:
# --> 286                 result = self.simulation.calculate_divide(var, period)
#     287         if (
#     288             target is not None
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate_divide(self, variable_name, period)
#     189             return self.calculate(variable_name, period = computation_period) / 12.
#     190         elif period.unit == periods.YEAR:
# --> 191             return self.calculate(variable_name, period)
#     192
#     193         raise ValueError("Unable to divide the value of '{}' to match period {}.".format(
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in partially_executed_formula(entity, period, parameters)
#      75         subset_entity = PopulationSubset(entity, mask_values)
#      76
# ---> 77         formula_result = formula(subset_entity, period, parameters)
#      78         formula_result = np.array(formula_result)
#      79
#
# ~/policyengine/openfisca-us/openfisca_us/variables/gov/states/mo/tax/income/income_tax/mo_income_tax.py in formula(tax_unit, period, parameters)
#      18     def formula(tax_unit, period, parameters):
#      19         mo_income_tax_before_credits = tax_unit(
# ---> 20             "mo_income_tax_before_credits", period
#      21         )
#      22         mo_property_tax_credit = tax_unit("mo_property_tax_credit", period)
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in __call__(self, *args, **kwargs)
#      23
#      24     def __call__(self, *args, **kwargs):
# ---> 25         return self.population(*args, **kwargs)[self.mask]
#      26
#      27     def __getattribute__(self, attribute):
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in partially_executed_formula(entity, period, parameters)
#      75         subset_entity = PopulationSubset(entity, mask_values)
#      76
# ---> 77         formula_result = formula(subset_entity, period, parameters)
#      78         formula_result = np.array(formula_result)
#      79
#
# ~/policyengine/openfisca-us/openfisca_us/variables/gov/states/mo/tax/income/income_tax/mo_income_tax_before_credits.py in formula(tax_unit, period, parameters)
#      15
#      16     def formula(tax_unit, period, parameters):
# ---> 17         taxable_income = tax_unit("mo_taxable_income", period)
#      18         rates = parameters(period).gov.states.mo.tax.income.rates
#      19         return rates.calc(taxable_income)
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in __call__(self, *args, **kwargs)
#      23
#      24     def __call__(self, *args, **kwargs):
# ---> 25         return self.population(*args, **kwargs)[self.mask]
#      26
#      27     def __getattribute__(self, attribute):
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in partially_executed_formula(entity, period, parameters)
#      75         subset_entity = PopulationSubset(entity, mask_values)
#      76
# ---> 77         formula_result = formula(subset_entity, period, parameters)
#      78         formula_result = np.array(formula_result)
#      79
#
# ~/policyengine/openfisca-us/openfisca_us/variables/gov/states/mo/tax/income/taxable_income/mo_taxable_income.py in formula(tax_unit, period, parameters)
#      17         tax_unit_itemizes = tax_unit("tax_unit_itemizes", period)
#      18
# ---> 19         mo_agi = tax_unit("mo_adjusted_gross_income", period)
#      20         mo_federal_income_tax_deduction = tax_unit(
#      21             "mo_federal_income_tax_deduction", period
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in __call__(self, *args, **kwargs)
#      23
#      24     def __call__(self, *args, **kwargs):
# ---> 25         return self.population(*args, **kwargs)[self.mask]
#      26
#      27     def __getattribute__(self, attribute):
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in partially_executed_formula(entity, period, parameters)
#      75         subset_entity = PopulationSubset(entity, mask_values)
#      76
# ---> 77         formula_result = formula(subset_entity, period, parameters)
#      78         formula_result = np.array(formula_result)
#      79
#
# ~/policyengine/openfisca-us/openfisca_us/variables/gov/states/mo/tax/income/adjusted_gross_income/mo_adjusted_gross_income.py in formula(tax_unit, period, parameters)
#      17         agi = tax_unit("adjusted_gross_income", period)
#      18         subtractions = tax_unit(
# ---> 19             "mo_qualified_health_insurance_premiums", period
#      20         )
#      21         return max_(agi - subtractions, 0)
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in __call__(self, *args, **kwargs)
#      23
#      24     def __call__(self, *args, **kwargs):
# ---> 25         return self.population(*args, **kwargs)[self.mask]
#      26
#      27     def __getattribute__(self, attribute):
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/populations/population.py in __call__(self, variable_name, period, options)
#      83             return self.simulation.calculate_divide(variable_name, period)
#      84         else:
# ---> 85             return self.simulation.calculate(variable_name, period)
#      86
#      87     # Helpers
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in calculate(self, variable_name, period)
#      93
#      94         try:
# ---> 95             result = self._calculate(variable_name, period)
#      96             self.tracer.record_calculation_result(result)
#      97             return result
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _calculate(self, variable_name, period)
#     123         try:
#     124             self._check_for_cycle(variable.name, period)
# --> 125             array = self._run_formula(variable, population, period)
#     126
#     127             # If no result, use the default value and cache it
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_core/simulations/simulation.py in _run_formula(self, variable, population, period)
#     230             array = formula(population, period)
#     231         else:
# --> 232             array = formula(population, period, parameters_at)
#     233
#     234         return array
#
# ~/opt/anaconda3/envs/policy_engine/lib/python3.7/site-packages/openfisca_tools/model_api/defined_for.py in partially_executed_formula(entity, period, parameters)
#      75         subset_entity = PopulationSubset(entity, mask_values)
#      76
# ---> 77         formula_result = formula(subset_entity, period, parameters)
#      78         formula_result = np.array(formula_result)
#      79
#
# ~/policyengine/openfisca-us/openfisca_us/variables/gov/states/mo/tax/income/subtractions/mo_qualified_health_insurance_premiums.py in formula(tax_unit, period, parameters)
#      37             (
#      38                 med_expense_deduction
# ---> 39                 / (med_dental_out_of_pocket + total_health_insurance_premiums)
#      40             ),
#      41             0,
#
# ValueError: operands could not be broadcast together with shapes (1001,) (2002,)
