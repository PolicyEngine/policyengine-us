# %%
from policyengine_us.data import EnhancedCPS_2023

EnhancedCPS_2023().generate()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from policyengine_us.data import EnhancedCPS_2023
#       3 EnhancedCPS_2023().generate()
#
# File ~/policyengine/policyengine-us/policyengine_us/__init__.py:11
#       1 """
#       2 This file defines our country's tax and benefit system.
#       3
#    (...)
#       8 See https://openfisca.org/doc/key-concepts/tax_and_benefit_system.html
#       9 """
# ---> 11 from policyengine_us.system import (
#      12     CountryTaxBenefitSystem,
#      13     Simulation,
#      14     Microsimulation,
#      15     IndividualSim,
#      16 )
#      18 from policyengine_us.data import *
#
# File ~/policyengine/policyengine-us/policyengine_us/system.py:53
#      47         self.parameters = set_irs_uprating_parameter(self.parameters)
#      48         self.parameters = backdate_parameters(
# ...
